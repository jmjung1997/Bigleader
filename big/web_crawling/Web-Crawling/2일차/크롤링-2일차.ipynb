# %%
# riss.kr 에서 특정 키워드로 논문 / 학술 자료 검색하기

#Step 1. 필요한 모듈을 로딩합니다
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
import time          

#Step 2. 사용자에게 검색 관련 정보들을 입력 받습니다.
print("=" *100)
print(" 이 크롤러는 RISS 사이트의 논문 및 학술자료 수집용 웹크롤러입니다.")
print("=" *100)
query_txt = input('1.수집할 자료의 키워드는 무엇입니까? : ')

#Step 3. 수집된 데이터를 저장할 파일 이름 입력받기 
ft_name = input('2.결과를 저장할 txt형식의 파일명을 쓰세요(예: c:\\py_temp\\riss.txt): ')
fc_name = input('3.결과를 저장할 csv형식의 파일명을 쓰세요(예: c:\\py_temp\\riss.csv): ')
fx_name = input('4.결과를 저장할 xls형식의 파일명을 쓰세요(예: c:\\py_temp\\riss.xls): ')

#Step 4. 크롬 드라이버 설정 및 웹 페이지 열기
s = Service("c:/py_temp/chromedriver.exe")
driver = webdriver.Chrome(service=s)

url = 'https://www.riss.kr/'
driver.get(url)
time.sleep(5)
driver.maximize_window()

#Step 5. 자동으로 검색어 입력 후 조회하기
element = driver.find_element(By.ID,'query')
driver.find_element(By.ID,'query').click( )
element.send_keys(query_txt)
element.send_keys("\n")

#Step 6.학위 논문 선택하기
driver.find_element(By.LINK_TEXT,'학위논문').click()
time.sleep(2)

#Step 7.Beautiful Soup 로 본문 내용만 추출하기
from bs4 import BeautifulSoup
html_1 = driver.page_source
soup_1 = BeautifulSoup(html_1, 'html.parser')

content_1 = soup_1.find('div','srchResultListW').find_all('li')
for i in content_1 :
    print(i.get_text().replace("\n",""))

#Step 8. 총 검색 건수를 보여주고 수집할 건수 입력받기
import math
total_cnt = soup_1.find('div','searchBox pd').find('span','num').get_text()
print('검색하신 키워드 %s (으)로 총 %s 건의 학위논문이 검색되었습니다' %(query_txt,total_cnt))
collect_cnt = int(input('이 중에서 몇 건을 수집하시겠습니까?: '))
collect_page_cnt = math.ceil(collect_cnt / 10)
print('%s 건의 데이터를 수집하기 위해 %s 페이지의 게시물을 조회합니다.' %(collect_cnt,collect_page_cnt))
print('=' *80)

#Step 9. 각 항목별로 데이터를 추출하여 리스트에 저장하기
no2 = [ ]        #번호 저장
title2 = [ ]     #논문제목 저장
writer2 = [ ]    #논문저자 저장
org2 = [ ]       #소속기관 저장
no = 1

for a in range(1, collect_page_cnt + 1) :
    
    html_2 = driver.page_source
    soup_2 = BeautifulSoup(html_2, 'html.parser')

    content_2 = soup_2.find('div','srchResultListW').find_all('li')
    
    for b in content_2 :    
        #1. 논문제목 있을 경우만
        try :
            title = b.find('div','cont').find('p','title').get_text()
        except :
            continue
        else :
            f = open(ft_name, 'a' , encoding="UTF-8")
            print('1.번호:',no)
            no2.append(no)
            f.write('\n'+'1.번호:' + str(no))

            print('2.논문제목:',title)
            title2.append(title)
            f.write('\n' + '2.논문제목:' + title)
            
            writer = b.find('span','writer').get_text()
            print('3.저자:',writer)
            writer2.append(writer)
            f.write('\n' + '3.저자:' + writer)

            org = b.find('span','assigned').get_text()
            print('4.소속기관:' , org)
            org2.append(org)
            f.write('\n' + '4.소속기관:' + org + '\n')
            
            f.close( )
            
            no += 1
            print("\n")
            
            if no > collect_cnt :
                break

            time.sleep(1)        # 페이지 변경 전 1초 대기 

    a += 1 
    b = str(a)

    try :
        driver.find_element(By.LINK_TEXT ,'%s' %b).click() 
    except :
        driver.find_element(By.LINK_TEXT('다음 페이지로')).click()
        
print("요청하신 작업이 모두 완료되었습니다")
# Out:
# ====================================================================================================
#  이 크롤러는 RISS 사이트의 논문 및 학술자료 수집용 웹크롤러입니다.
# ====================================================================================================
# 1.수집할 자료의 키워드는 무엇입니까? : 자원
# 2.결과를 저장할 txt형식의 파일명을 쓰세요(예: c:\py_temp\riss.txt): 123
# 3.결과를 저장할 csv형식의 파일명을 쓰세요(예: c:\py_temp\riss.csv): 123
# 4.결과를 저장할 xls형식의 파일명을 쓰세요(예: c:\py_temp\riss.xls): 123
# 1地下水資源의 效率的인 管理方案에 관한 硏究최연재慶熙大學校1998국내석사RANK : 27772927복사/대출신청
# 복사/대출신청
# 2우리나라 自願奉仕 租織의 運營效率化에 관한 硏究김영성東亞大學校 政策科學大學院2000국내석사RANK : 27772927원문보기인간이 서로 도우려는 정신은 인간의 아름다운 본성이며 상호협력과 공존의 무리를 지어 살아야 한다는 존재 그 자체일 것이다. 급속한 사회변화는 개인의 삶과 인간만이 가지는 가치를 위협하고 산업사회로 인한 이기주의는 인간관계를 약화 파괴할 뿐만 아니라 심각한 개인 및 사회문제를 야기 시킨 요인으로 지적되고 있다.가장 근본적인 인간관계의 중요성으로, 최선의 방법은 자원봉사활동을 통해서 가족과 이웃을 다시 생각하게 하고 인간의 기본 욕구와 기초적 의식 복구와 함께 사회공동체를 되찾아야 함이 시급한 실정이다.따라서 본 연구는 급변하는 사회변동에 대비하여 보다 인간의 기본적 욕구를 충족시켜 공적·제도적인 접근을 구체화하고, 우리나라 자원봉사 조직의 운영 효율화를 통해 그 활성화 방안을 제시하고자 각종 문헌 및 간행 자료를 집중적으로 활용하였다.이 글에서는 먼저 자원봉사활동의 특성 및 선진국의 자원봉사활동에 대하여 살펴보았으며, 그 결과 자원봉사조직의 운영과 구성체계를 3단계로 즉, 추진, 관리, 지원 체계로 나누어 분석해 볼 필요가 있음을 알 수 있었다. 그러므로 자원봉사는 각종 유기적인 관계의 추진역할, 자원봉사자와 관리자의 효율적인 활동의 관리, 사회적 외부환경으로부터 구체적으로 지원하는 지원기능을 바탕으로 우리나라 자원봉사활동의 역사적 배경을 알아보았고 각종 프로그램 현황을 시설별, 기관별 및 가정, 이웃지역간 별로 검토해 보았다. 그 결과 우리나라 자원봉사조직의 운영실태분석을 추진, 관리, 자원체계별로 개선방안을 구체화시켜 살펴볼 수 있었다.이와 같은 일련의 결과를 고려해 볼 때, 우리나라 자원봉사조직의 선진적인 운영 효율화를 위해서는 정부와 기업, 관리자와 자원봉사자는 보다 체계적이고 유기적인 참여와 통합을 기하는 것이 성숙한 자원봉사활동을 정착시킬 수 있다고 하겠다. The spirit of helping one another is a beautiful aspect of human nature. It also means that human beings need ta cooperate and coexist. Rapid social changes, however, have brought about the threat on individual life and human values. Egoism following the industrial society has weakened human relations and caused lots of serious personal and social problems.The best method to regain fundamental and foremost human relations is voluntary service activities through which we can realize the importance of family and neighborhood, recover basic human needs and consciousness, and rebuild desirable social community,This research, therefore, aims to substantiate the public and institutional accesses to basic human desire and to devise activation plans for managerial efficiency of voluntary service organizations in Korea. Various literature and materials were intensively used. This study considered the characteristics of voluntary service activities at large and in some advanced countries. As a result, a voluntary service system could be analyzed in three aspects of promotion, management, and assistance.Then, the historical background of voluntary service activities in Korea was examined in terms of organic promotion, efficient management of volunteers and managers, and concrete assistance of the external social environment. Also, the current situation of voluntary service programs was reviewed by facilities, institution, house, and neighborhood.Lastly, some substantial proposals for improving the present voluntary service activities could be made in the above-mentioned three aspects. In short, more systematic and organic participation and unity among the government, enterprises, managers, and volunteers will surely lead to more mature and advanced voluntary service activities in this land.
# 원문보기
# In conclusion, it is expected that the research involving online platforms and town-making to prevent communities from disappearing will be actively conducted, and accordingly, this will lead to increase in interest and creative studies through interdisciplinary convergence.gnition by characteristics of making resource circulation towns and platform services.  ree fields mentioned above are rare, even though there is a great deal of interest and research on online platforms.r endangered communities.
# 원문보기
# 목차검색조회
# 음성듣기
# 4고학력 기혼여성의 자원봉사 활성화 방안에 관한 연구이희자대전대학교 경영행정대학원1999국내석사RANK : 27772927원문보기자원봉사는 복지국가의 기초이며, 민주 시민사회의 주인인 주민에 의한 복지공동체를 실현하는데 가장 핵심적인 활동이라고 할 수 있다. 민주사회의 발전은 사회구성원들의 공동체의식과 지역사회 주민들의 상호협조에 있으므로 시민의 자발적인 자원봉사에의 참여를 통하여 복지 공동체가 성숙될 수 있을 것이다. 그러므로 자원봉사란 민간이 복지에 참여하는 것으로서 시민사회로 성장하기 위하여 필요한 과제이다. 시민활동으로서의 자원봉사활동은 시대의 흐름에 따라 고조된 관심에 비하여 자원봉사에 대한 참여율은 아직까지 미흡한 수준이고 활성화되어 있지 않은 실정이다. 자원봉사활동은 장기적, 지속적으로 모든 국민이 참여해야 하며 지역사회를 중심으로 이루어져야 한다. 즉 지역주민이 갖고 있는 풍부한 자원을 활용함으로써 공공부문의 부족함을 보충할 수 있고 활동에 참여하는 개인의 입장에서는 유휴인력을 가지고 사회에 기여함으로써 얻게 되는 만족감을 가져다준다. 특히 고학력 기혼여성의 자원봉사활동은 유휴여성인력의 활용이라는 측면과 함께 전문기술을 활용할 수 있어 자원봉사활동의 내용을 확대시킬 수 있는 장점을 가지고 있다. 하지만 고학력 기혼여성의 자원봉사활동에 대한 중요성을 간과하고 있는 현실에서 본 연구에서는 대전지역 기혼여성들의 자원봉사활동의 현황과 자원봉사활동에 대한 태도를 알아보고 그 결과에 따라 고학력 기혼여성들의 자원봉사활동을 활성화하기 위한 방안을 다음과 같이 모색해 보았다. 첫째는 자원봉사활동에 대한 충분한 홍보와 인식제고가 필요하다. 자원봉사활동을 사회복지서비스의 제공이라는 차원에서 한정시킬 것이 아니라, 지역사회의 발전을 도모하는 방향으로 인식의 전환이 필요하다. 이는 자원봉사활동에 대한 홍보와 재교육을 통해 이끌어 낼 수 있으며, 홍보와 재교육의 역할은 국가와 자원봉사안내센터에서 담당하여 체계적으로 활동할 수 있어야 한다.둘째는 자원봉사활동에 대한 다양한 프로그램과 활동처를 확보하는 것이다. 고학력 기혼여성의 자원봉사활동을 활용하기 위해서는 전문기술을 받아들일 수 있는 프로그램과 활동처가 확보되어야 한다. 이를 위해서는 고학력 기혼여성의 전문기술을 축적할 수 있는 '인력은행'과 같은 시장이 운영되어 적재적소에 적절히 배치할 수 있는 유연성을 발휘해야 할 것이다. 셋째는 자원봉사활동의 지속성을 유지하기 위해 소그룹활동을 지원·강화하고 정부와 기관, 자원봉사자 삼자간의 협력을 유지함으로써 보다 유기적인 활동을 가능하게 해야 한다. 현재 정부의 지원은 매우 미약한 실정인데, 대전지역 기혼여성들은 자원봉사에 대한 '사회적 분위기의 조성'을 중요한 정부의 역할로 꼽았다. 따라서 정부의 고학력 기혼여성들의 자원봉사 욕구를 파악하여 이를 지원하고, 궁극적으로 제도화할 수 있는 노력이 필요하다.넷째는 자원봉사활동이 전체 사회에서 지지체계를 형성하여 활성화될 수 있는 사회 전반적인 분위기가 향상되고, 이를 통해 고학력 기혼여성에게 자원봉사활동의 역할을 부여하고 확대해야 한다. 자원봉사활동 인구의 저변확대를 통해 전체적인 사회 분위기를 고조시키고, 고학력 기혼여성들에 대해서는 자기강화훈련과 사회적인 인식의 변화가 맞물려 창의적인 서비스의 개발을 이루어내야 하겠다.
# 원문보기
# 5노인자원봉사자 만족도 향상을 위한 연구 : 원주시와 횡성군 노인자원봉사자를 중심으로김종윤중부대학교 원격대학원2005국내석사RANK : 27772927원문보기최근 우리나라는 급속한 경제성장으로 생활수준의 향상과 보건·의료기술의 발달로 평균수명이 증가하여 노인인구가 급속도로 증가함으로써 빠른 속도로 고령화 사회에 진입하고 있다. 이러한 현상은 노인 복지에 대한 준비가 병행되지 않음으로 인하여 심각한 사회문제로 대두하게 되었다.본 논문은 다양한 노인문제 중에서 무역활로 인한 정체성의 문제와 고독의 문제를 해결하고 나아가 삶의 보람을 가질 수 있는 노인자원봉사활동에 논점을 두고 봉사활동의 지속성을 위하여 만족도에 영향을 주는 영향요인을 분석함으로써, 노인자원봉사활동의 만족도를 향상 시킬 수 있는 방안을 제시하고자 한다. 노인자원봉사활동은 노인 자신과 사회의 공익을 위해서도 보람 있고 유익함에도 불구하고 실제 참여도가 낮은 편이다.본 연구의 목적을 달성하기 위하여 노인자원봉사자의 만족도와 관련되는 요인을 살펴보기 위하여 다음과 같은 가설을 설정하고 경험적 검증을 하여 보았다.첫째, 노인자원봉사자의 사회경제적 배경요인(성별, 연령, 학력, 종교, 과거직업 등)의 차이가 봉사활동 만족도에 영향을 미칠 것이다.둘째, 노인자원봉사자의 활동관련요인(봉사업무 인식도, 난이도, 업무의 적절성)이 노인자원봉사활동의 만족도에 영향을 미칠 것이다.셋째, 노인자원봉사자의 대인관계(대상자, 동료봉사자, 담당직원)가 봉사활동 만족도에 영향을 미칠 것이다.넷째, 노인자원봉사자의 관리방법(교육지원, 보상)이 봉사활동 만족도에 영향을 미칠 것이다.이러한 연구 가설을 검증하기 위하여 보건 산업이 강세를 보이고 있는 원주시/횡성군에 거주하는 노인자원봉사자 122명을 대상으로 설문지에 의한 면접조사를 통하여 불성실한 24부를 제외한 98부에서 다음과 같은 결과를 얻었다.첫째, 조사대상인 노인자원봉사자의 사회경제적 배경에서 성별은 여성이 남성보다 2배정도 많고, 봉사업무 내용에서는 여성이 남성보다 부정적으로, 개인성장에서는 긍정적으로 나타나고 있으나 전체적으로 긍정적인 봉사자가 많은 것으로 나타났다.연령은 55~64세 67%, 65~69세 12.4%, 70~74세 9.3%, 75~79세 7.2%, 80세이상 4.1%가 다양하게 분포되어 있지만, 연소노인층이 상대적으로 매우 높게 나타나고 있다. 노인자원봉사자 대부분 연령층에서는 봉사시간이 생각보다 많다고 생각하며, 연령이 많아질수록 봉사시간에 부담을 많이 갖고 있는 것으로 나타났다. 봉사내용 난이도에서는 연령별로 역U자 곡선을 보이고 있으며, 고령노인층에서 어렵지 않다는 응답자가 많게 나타나는 것은 건강수준향상과 이타적인 높은 동기가 있기 때문이다.연령별 봉사활동 경비보조에서는 대부분 자부담으로 봉사활동을 하고 있으며, 전체적으로 종교를 가진 봉사자가 많아 노인자원봉사의 참여에 중요한 관련이 있음을 보여준다. 현재 가족동거 형태에서는 정서적/경제적으로 안정된 가족이 적극적으로 노인자원봉사활동에 참여하고 있는 것으로 나타났다.조사대상자 건강상태는 67.4%가 건강하다고 응답하였고, 자원봉사경험은 84.7%가 경험이 있다고 응답하였다. 건강에 대해 긍정적으로 생각하는 노인층과 봉사활동 경험이 있는 노인들을 대상으로 보다 적극적인 홍보와 유인책을 통하여 자원봉사활동에 참여를 유도함으로써 날로 증가하는 노인문제의 해결과 지역사회 복지에 유용한 자원으로 이용되어야 할 것이다.둘째, 봉사활동관련 업무에서는 봉사활동이 타인의 복지에 영향을 주는 사회공헌성에서 봉사자의 만족도 79.5%, 노력결과에 따른 결과확인을 통하여 느끼는 자아성취감은 61.5%, 주어진 일이 끝날 때까지 지속하는 신뢰도는 73.5%로 긍정적으로 나타났다. 봉사업무 난이도에서 시간부담정도는 61.2%가 부정적으로 나타났다.봉사활동 내용의 복잡정도, 봉사시간/거리의 부담정도에서 봉사활동을 부담스럽게 느끼는 부분이 많아 각 연령층별로 수중에 맞는 업무를 체계적으로 분장하여 거주지별로 이동이 용이하도록 배치되어야 노인자원봉사활동이 활성화 될 수 있을 것으로 보인다.셋째, 노인자원봉사자의 대인관계에서는 대상자, 동료, 담당직원과의 관계는 매우 긍정적으로 응답하였으나, 봉사자의 노력으로 대상자의 변화/성과 정도는 35.7%가 부정인 응답이 나왔다. 따라서 자원봉사자는 단기간에 대상자가 자신의 노력으로 변화와 성과가 없다고 하여도 지속성과 인내를 가지고 실천하는 것이 필요할것으로 보인다.노인자원봉사자의 관리방법으로 교육지원에서는 41%가 부정적으로 응답하였다. 교육지원사업은 사회복지협의회에서 실시하고 있으나 봉사활동교육이 체계적으로 이루어지지 않고 있음을 보여준다. 그러므로 노인자원봉사활동이 활성화되기 위해서는 사전교육이 체계적으로 이루어져야 한다. 노인자원봉사자 관리방법으로 보상에서는 경비지원 72.1%, 포상 54.7%가 부정적으로 응답하였다. 이는 퇴직 등 원인으로 경제적으로 어려움과 무역할, 소외감을 갖는 노인에게는 봉사활동 활성화를 위해서 일정 수준의 경비지원과 포상, 보험제도 마련이 제도화되어야 할 것이다.넷째, 자원봉사활동 만족도 요인에서는 이타적인 동기에 의한 만족도가 72.3%로 대부분 긍정적으로 응답하였으나, 봉사자 노력으로 대상자 상황변화 인식정도에서는 40.2%가 부정적으로 응답하였다. 그리고 이기적 동기에 의한 만족도도 비교적 긍정적으로 높게 나타났다. 이는 대부분의 자원봉사자가 이타적인 동기에서 봉사활동을 시작하고 있지만, 이기적인 동기에 의해서 더 많은 영향을 받고 있는 것임을 알 수 있다. Average life span has been recently extended due to improvement of living standard and development of health and medical treatment technology by rapid economic growth so that our country rapidly enters into an aging society.Since we haven't prepared senior welfare, this kind of phenomenon has been come to front as serious social issue.This study is to suggest the solutions of identity issue due to non-participating and loneliness among various issues of senior citizens and to focus on volunteering activity of senior citizen that enables to have fruitful life in advance. In addition, the author is to analyze influence factor on satisfaction in order to continue volunteering activity so that the way is suggested to improve satisfaction of volunteering activity by senior citizen.Although volunteering activity by senior citizen is very fruitful for public interest of society as well as senior citizens, in fact, participation ratio is relatively low.To achieve the object of this study and to look into factors related to satisfaction of senior citizen volunteers, we have performed experiencing verification after establishing the follow assumptions.Firstly, the difference of social and economic background of senior citizen volunteers (gender, age, academic background,  ...
# 원문보기
# 6학생상담자원봉사 활동의 현황 및 만족도에 관한 연구 : 서울지역을 중심으로김지수중앙대학교 사회개발대학원2008국내석사RANK : 27772927원문보기목차검색조회음성듣기This study aims at providing general plan of increasing satisfaction and efficiency of counseling volunteerism which intends to help healthy growth and development of juveniles instead of insufficient professional human resources by understanding the current situation and analyzing factors that affect counseling volunteerism. For this purpose, two main research subjects are brought up:1. What are the current situations of general facts (personal capabilities) of volunteers, contents of counseling volunteerism, counseling training experiences, and volunteer institutions?2. Is there any difference in level of satisfaction according to factors addressed above?Interviewees of this study are 277 volunteers who completed basic counseling volunteerism courses offered by Seoul Education Research & Information Institute, and is now volunteering at elementary, middle, and high schools in Seoul under the command of Seoul Metropolitan Office of Education.Collected data were analyzed by using SPSS 12.00 statistics program, and each factor was computed by frequency and percentage. Mean and standard deviation were calculated if available. To figure out whether there is difference in level of satisfaction according to contents of counseling volunteerism, counseling training experiences, and volunteer institution, T-test and ANOVA were applied, and some results are derived.First, 40% of them are in their forties, 33.2% of them are protestant, 84.8% of them have university diplomas, and 70.5% of them are housewives. Also, 46.9% of them have children who attend middle or high schools, and most of them are volunteering at middle schools. This shows that with high educational degree, volunteers have deep concerns and experiences about juvenile issues through their children, so that they have basic quality and capability for volunteer activity.Second, 34.2% of interviewees answered participation motive is that it might be helpful for educating their children. The largest portion of volunteerism period is between one and two years with 23.8% and the length is decreasing. However, those who answered others mostly volunteered more than 7 years, which signifies that if there are sustainable training and thorough control, counseling volunteerism can be revitalized. Counseling processes which solve juvenile problems are mainly conducted by group, yet clients are more satisfied when group counseling goes hand in hand with individual counseling. They are generally satisfied with the results.Third, in terms of counseling training experience, 33.3% of them who did not major in juvenile education did not take additional courses, and they are now doing volunteer counseling with 60 hours of basic courses. Accordingly, most of interviewees recognize the need of additional training for improving counseling techniques.Fourth, 58.1% of interviewees mostly counsel after school. 57% answered they have private office, and 42.6% answered they have not, which mean they do not have enough space to prepare and evaluate their counseling. The portion of volunteers who are doing volunteer activities connected to professional counselors is low with 32.1%, but they were highly satisfied with the results of connection. Volunteers are paid the least such as transportation fee, yet 89.9% of them wish to continue their volunteering at current institutes. 21.3% say if one wants to quit, it is because the counseling result does not meet the expectation, which implies the lack of counseling abilities or techniques negatively affects sustainable counseling volunteerism. Therefore, 'continuous retraining of counseling volunteers,' and 'development and supply of various counseling programs' are needed as political supports for revitalization.Fifth, satisfaction measurement of student counseling volunteers is conducted using several aspects such as desire for experience, desire for social conta ...
# 원문보기
# 목차검색조회
# 음성듣기
# 7자원봉사센터 활성화방안에 관한 연구 : 광주광역시를 중심으로변춘섭조선대학교 정책대학원2006국내석사RANK : 27772927원문보기목차검색조회음성듣기As society is well-organized and well-managed, more people share what they have with others. That the society we dream should be happy community indicates that the people are generous to share their happiness with others in it. To find a way for a community named Gwangju to be happy is the first and last step of voluntary service.This study examines the current status and problems of volunteer centers in Gwangju and discusses their activation plans in terms of organization, personnel, finance and connective systems, hoping that Gwangu can be an example city of volunteer service.First, the subjects of management should unify organizations as a private corporation system to have incorporated systems to activate them. In respect to standardization of management, power of internal organizations should be reinforced for a base of activation The enters should organize management systems who have been independently taken care of through standardization of task manuals and prepare systems through which capable volunteers can be produced through standardization of management and education of volunteers.Second, for activation of personnel management, volunteers should be expanded. For the purpose, programs to collect volunteers should be developed and professionals who are appropriate for the programs should be excavated through close cooperation with volunteer organizations rather than simple collection of volunteers. Systems and programs to recognize private interests of volunteers should be developed to attract more volunteers and to make them concentrate on their voluntary service. Now when the average period of working as voluntary service managers and professionals is less than two years, expecting their absolute dedication to voluntary service is not appropriate for the society composition principle of this capitalized society. To excavate more capable professionals, centers should prepare new plans to attract them.Third, in respect to finance, the budget should be urgently secured. In an assumption that project equals budget, centers could not deal with securement of project expense properly. There is a need that recognition on finance of centers should be changed: First, the budget support from the government is very scanty. Second, the efforts to secure independent management of the centers are unreasonable. If the money from the government is insufficient, the centers should prepare the expense for the project through fund raising, but their efforts are lacking. To secure the members in private corporation systems, supportive forces should be prepared through general meetings, which secures foundations for stable projects.Fourth, if roles are not properly segmented between centers and organizations in terms of activation through connective networks in community, centers can not work as a central base. They should not think that they can deal with everything themselves, and each center should develop what it can do well at the maximum for development of its community. Extensive voluntary service networks over the whole community should be prepared. The preparation for demand and supply network of voluntary service is the most urgent and the staff in charge of the centers should share information on management through preparation of management networks, which contributes to active management. To secure reliability for joint production through preparation of private and public networks of volunteers is required.
# 원문보기
# 목차검색조회
# 음성듣기
# 본 연구는 일반사회단체와 성격이 다른 자원봉사조직인 상록자원봉사단원들은 풍부한 공직경험과 전문적인 재능을 사회에 기부한다는 의미를 가진다. 자원봉사조직의 사회자본이 조직성과에 많은 영향을 미치는 것으로 나타났다. 상록자원봉사단원으로서의 자부심은 대체로 높은 편이었으나 봉사활동을 전개하는데 있어서는 많은 어려움과 현실적인 문제들이 있는 것으로 나타났다. 본 연구를 통해 얻은 정책적 시사점은 사회봉사조직 거버넌스 체계구축, 자원봉사조직의 사회자본 육성, 자원봉사조직 인력의 편중과 고령화문제해결, 그리고 자원봉사조직의 활성화 방안 등 이다.리는 변수들 간의 상관분석과 회귀분석을 실시하였다. 자원봉사조직의 사회자본과 성과간의 상관분석에서 네트워크와 호혜성간 가장 강한 상관관계가 있는 것으로 나타났으며 사업성과는 신뢰성과 네트워크와 상관계수가 높게 나타났다. 운영성과는 사회자본 요인과 약한 상관관계를 보이고 있다. lunteer activities. The policy implications of this study were the establishment of a social service governance system, the development of social capital of volunteer organizations, the resolution of the bias and aging of volunteer workers, and the activation of volunteer organizations. 1960년대 이후 급격한 산업기술의 발달과 경제 발달에 따라 우리나라에도 자원봉사조직의 역할과 기능이 증가하고 다양해지면서 봉사조직의 성과에 대한 관심도 증가하고 있다. 최근 우리나라에서 자원봉사활동 참여와 이에 대한 인식의 변화를 가져오게 한 계기는 ‘07 태안 원유 유출 사건, ‘86아시안게임과 ‘88올림픽게임, 그리고 최근에 2018 평창 동계올림픽 등의 활동 과정에서 증폭되었다고 할 수 있다. 특히 1995년부터 자원봉사활동의 본격적인 활성화와 체계적 관리를 위해 학생(청소년)봉사활동과 대학 사회봉사활동, 여성 자원봉사활동, 기업 자원봉사활동, 종교 자원봉사활동 등의 활동이 이루어지기 시작하였다. 이는 인성교육 계발과 공동체의식 함양, 인적자원 활용, 긍정적 자아형성으로 사회구성원으로서의 자부심과 사회복지에 공헌, 지역사회에 제공 공헌 등 지역민과의 유대 및 신뢰감 형성을 목적으로 하였다. 특히 ‘2018평창동계올림픽’ 행사에서 자원봉사자들의 활동은 자원봉사활동을 통해 사회 환원의 일환으로 나라사랑, 이웃사랑을 몸으로 실천하려는 협동정신 함양의 변화를 가져왔으며, 민·관뿐만 아니라 다양한 계층에서 다양한 형태의 자원봉사조직이 활동하고 있다.
# 원문보기
# 목차검색조회
# 음성듣기
# 9社會福祉 自願奉仕者管理 改善方案에 관한 硏究 : 天安市를 中心으로최원석湖西大學校 行政大學院2001국내석사RANK : 27772927원문보기Recently every field of Korean society is being increasingly interested in the activity of volunteers, but there are many difficulties for the social welfare institutes or facilities utilizing them to effectively manage and make them keep volunteering.  Present study examines which way of management of volunteering should be used to encourage the successiveness of volunteer's activity, and how the managers of volunteers in social welfare institutes and facilities really do for managing volunteering.To suggest reforming measures in managing social welfare volunteers, present study has some purposes, such as: first, to understand theoretically the management process of volunteer based on studies of references and existing papers; and second, to investigate whether there is a difference of volunteering according to the managing methods of social welfare institutes or facilities utilizing the volunteers like the ways to recruit and give publicity, to single out and post, to educate and train, and to manage them ex post facto.  To achieve the purposes, a toll of managers who are currently charging management department of volunteering in 35 social welfare institutes and facilities located in Chonan, Chungchongnam-do was practiced.  Present study analysed the correlation between management process of volunteer and through cross analysis, but few statistically significant difference was found. Measures of effective management of each process are:For the way to recruit and give publicity, first, the role of supporting and raising body for volunteer activity should be reinforced for the institutes and facilities which is weak in recruiting and giving publicity; and second, for more effective recruiting,  media for publicity should be diversified.For effective way to single out and post, it is necessary to reflect enough the section of volunteering activity and desire of volunteer.  For effective way to educate and train, general education and special education fit to each facility should be properly balanced.The management of volunteers ex post facto should be approached with the consideration that they are guests of social welfare institute or facility.  And, by making a data of evaluation on the activity of each volunteer, the burden about evaluation should be reduced through chatting on volunteer's personal hobby, concern or interest.  The reforming measures in terms of systemic support on utilizing volunteer are: First, it is needed to secure stable finance of volunteer facility, so as to develop a program meeting to volunteer's desire and operate institute or facility.  A measure to enlarge the financial support by local authority in a long term has to be considered, and a variety of subsidies from central administration should be offered in a short term. Second, it is needed to set up a professional agency for volunteer, that is, an integral legal body so as to extend the role of supporting and raising organization for volunteer activity.  Third, it is required to introduce a social rewarding system on use of volunteering, that is, the authorization system of volunteering career, by serving various benefits through tex support, practicing supplements and events for volunteers to give motivation and encourage morale, and awarding for excellent volunteering in national event.The above is the suggestion on reforming management of systemic support on management process of volunteer and utilizing volunteering regard to effective management of volunteer.  To activize volunteering activity in Korea, the administration and institute should be concerned about the firm belief about volunteering spirit and value.  When equiped professional competence and practical effort, the activity of volunteers may be realized among our life.There exists a regional limitation in present study since the research boundary is restricted within Chonan area.  And coordinated resear ...
# 원문보기
# 10자원복지(봉사)단체협의회·종합센터 기능인지에 관한 연구 : 京畿道31곳 시·군 中心으로정윤지강남대학교 대학원2000국내석사RANK : 27772927원문보기본 연구는 1996년 경기도용역사업에 의해 강남대학교 사회복지대학의 김영호 교수를 연구위원장으로 하는 연구팀에 의하여 "자원복지(봉사)센터 설치 및 운영에 관한 연구"를 기초로 경기도 시·군에 자원봉사센터·협의회 모형이 세워졌고 현재 운영중이다.이러한 전개 과정 속에 31곳 시·군의 실무자들은 이 모형에 대한 기능이 실무자들에게 어떻게 이해되고 있으며 또 종합자원봉사센터로만 운영하자는 주장이 있어 실무자들의 혼선 등이 문제가 되면서 실무자들의 협의회·센터의 기능인식을 알아보고 대안을 제시하고자 하였다.첫째 자원봉사센터 설치 및 시행과정에서 성과중심으로 급속히 이루어져 정확한 이해 없이 시작되었다. 이것을 관할 부서에서 기초교육 및 공청회와 토론 위에 이루어졌더라면 그 기초가 튼튼했으리라 생각된다.둘째 비전문가 및 봉사의 경험이 없는 실무자의 업무로 지역사회 자원봉사의 발전이 더디고 있다. 물론 예산이 없다는 이유로 이런 현상이 나타나지만 자원봉사센터의 발전을 기대하려면 전문적(사회복지사) 직원과 그에 상응하는 처우부터 개선하여 활성화를 가져오게 해야 한다.셋째 31곳 시·군 중 시·군 직영체제로 활동하는 센터는 협의회 구성을 번거로워 하고 있다. 사회단체 지원법 통과이후 많은 단체들이 신고에 의해 등록이 되고 또한 프로그램을 공모 출품하여 지원을 받을 수 있는 새로운 길이 열렸다.수많은 NGO, NPO등의 단체를 연계할 수 있는 전문매개체로서의 역할은 복지(봉사)센터가 해야하며 단체를 규합할 수 있는 힘이 협의회인 것이다. 일본의 예를 보더라도 협의회는 기본이며 협의회 기능이 전문분과별로 나뉘어져 그 영역이 확대되고 있다. 우리의 시작은 모든 단체 구분 없이 규합하고 있지만 반드시 전문분야별로 협의회가 구성되고 그 협의체가 그 지역사회 전체 협의회에 회원으로서 조직적이고 체계적인, 전문적인 자원복지(봉사)의 발전을 이루는 것이다.물론 센터·협의회 운영가운데 역할의 중복, 기능발휘의 걸림돌, 책임권한 소재 불분명 등의 이유는 철저하게 규명해야한다.덧붙여 협의회가 운영하는 센터의 모델에 대해 거부반응이 있는 이유로 두 가지 점을 유의할 필요가 있다.하나는 자원봉사단체의 성격에 관한 논란이 계속되고 있는 것이 현실이고 다른 하나는 개인 자원봉사자의 증가 추세와 관련된 점이다.넷째 이 조사를 통해서 심도 있는 자원복지(봉사)철학 교육의 필요성과 협의회를 구성하는데 있어서 지역사회의 상황을 개관적으로 파악하는 것은 중요한 관건이다. 31곳 시·군의 경우 도시형, 농가형, 도시·농가형등 다양한 환경에 그 처한 위치가 다 다르다. 그러므로 각 지역사회는 자원복지(봉사)의 철학을 이해하여 모든 사람들이 참여할 수 있는 토대로 그 기초를 다져나가야 할 것이다. This study has been conducted based on "Establishment and Operation of Volunteer Community Center" by the research team with Professor Young-Ho Kim, Social Welfare College, Kangnam University as chairman requ ested according to the Kyonggi Province Service Project in 1996. Thereafter, models of volunteer community center and council have been established and in operation in cities and guns of Kyonggi Province.So this study is to find the understanding of workers about the models in 31 places of cities and guns of Kyonggi Province, to investigate the recognition of workers about the function of the center and council of volunteer organizations and to offer measures to solve related problems since problems such as confusion among workers have occurred owing to assertions that the centers should be operated as general volunteer community centers.First, the establishment and operation of the volunteer community centers started without the accurate understanding of workers about the centers because this project was carried out rapidly only by focus on achievements. If this project had been carried out based on the basic education, public hearings and discussions about the center, its foundation would have been strong.Second, the development of the community volunteer service is slow because of the service of non-experts or inexperienced workers. Of course, this phenomenon blames the lack of budget, but the development of the volunteer center needs the specialized workers(Authorized Social Welfare Administrators) and proper treatments to them for its activation.Third, the centers, which are directly operated by city or gun, are reluctant to the establishment of council. After Social Association Support law was in enforcement, lots of organizations registered for this purpose, and a new way is opened to the support through the recruiting and submitting of programs.The volunteer community center should play a role of special medium to link with other numerous organizations such as NGO and NPO. The strength to consolidate such organizations is the council. Take, for instance, Japan. In Japan the council is basic. The function of council is divided into special sections and its area is being expanded. We started including all organizations, but the coucil must be composed by special area and make systematic and organized development of volunteer welfare(service) as a member of all organizations in the community.Of course, the role overlapping, hinderance to function and inconspicuous obligation and responsibility of the center and the associ ...
# 원문보기
# 검색하신 키워드 자원 (으)로 총 77,238 건의 학위논문이 검색되었습니다

# %%
# Step 10. 수집된 데이터를 xls와 csv 형태로 저장하기
import pandas as pd 

df = pd.DataFrame()
df['번호']=no2
df['제목']=pd.Series(title2)
df['저자']=pd.Series(writer2)
df['소속(발행)기관']=pd.Series(org2)

# xls 형태로 저장하기
df.to_excel(fx_name,index=False, encoding="utf-8" , engine='openpyxl')

# csv 형태로 저장하기
df.to_csv(fc_name,index=False, encoding="utf-8-sig")

print('요청하신 데이터 수집 작업이 정상적으로 완료되었습니다')
# Out:
# ====================================================================================================
#  이 크롤러는 RISS 사이트의 논문 및 학술자료 수집용 웹크롤러입니다.
# ====================================================================================================
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [2], in <cell line: 14>()
#      12 print(" 이 크롤러는 RISS 사이트의 논문 및 학술자료 수집용 웹크롤러입니다.")
#      13 print("=" *100)
# ---> 14 query_txt = input('1.수집할 자료의 키워드는 무엇입니까? : ')
#      16 #Step 3. 수집된 데이터를 저장할 파일 이름 입력받기
#      17 ft_name = input('2.결과를 저장할 txt형식의 파일명을 쓰세요(예: c:\\py_temp\\riss.txt): ')
#
# File C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\kernelbase.py:1075, in Kernel.raw_input(self, prompt)
#    1071 if not self._allow_stdin:
#    1072     raise StdinNotImplementedError(
#    1073         "raw_input was called, but this frontend does not support input requests."
#    1074     )
# -> 1075 return self._input_request(
#    1076     str(prompt),
#    1077     self._parent_ident["shell"],
#    1078     self.get_parent("shell"),
#    1079     password=False,
#    1080 )
#
# File C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\kernelbase.py:1120, in Kernel._input_request(self, prompt, ident, parent, password)
#    1117             break
#    1118 except KeyboardInterrupt:
#    1119     # re-raise KeyboardInterrupt, to truncate traceback
# -> 1120     raise KeyboardInterrupt("Interrupted by user") from None
#    1121 except Exception:
#    1122     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# # 4-1 연습 문제로 실력 굳히기

# %%
#Step 1. 필요한 모듈을 로딩합니다
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
import time          

#Step 2. 사용자에게 검색 관련 정보들을 입력 받습니다.
print("=" *100)
print(" 이 크롤러는 RISS 사이트의 논문 및 학술자료 수집용 웹크롤러입니다.")
print("=" *100)
query_txt = input('1.수집할 자료의 키워드는 무엇입니까? : ')

#Step 3. 수집된 데이터를 저장할 파일 이름 입력받기 


#Step 4. 크롬 드라이버 설정 및 웹 페이지 열기
s = Service("c:/py_temp/chromedriver.exe")
driver = webdriver.Chrome(service=s)

url = 'https://www.riss.kr/'
driver.get(url)
time.sleep(5)
driver.maximize_window()

#Step 5. 자동으로 검색어 입력 후 조회하기
element = driver.find_element(By.ID,'query')
driver.find_element(By.ID,'query').click( )
element.send_keys(query_txt)
element.send_keys("\n")

print('''위 키워드로 아래의 장르 중 어떤 장르의 정보를 수집할까요?: .
         1. 학위논문    2.국내학술논문    3.해외학술논문    4.학술지     5.단행본       6.공개강의      7.연구보고서''')
select_number=input()
if select_number=='1':
    telecomName = "학위논문"
elif select_number=='2':     
    telecomName = "국내학술논문"; 
elif select_number=='3':     
    telecomName = "해외학술논문";
    
elif select_number=='4':     
    telecomName = "학술지";
    
elif select_number=='5':     
    telecomName = "단행본";
    
elif select_number=='6':     
    telecomName = "공개강의";
elif select_number=='7':     
    telecomName = "연구보고서";
 
      


fc_name = input('3.결과를 저장할 csv형식의 파일명을 쓰세요(예: c:\\py_temp\\riss.csv): ')
fx_name = input('4.결과를 저장할 xls형식의 파일명을 쓰세요(예: c:\\py_temp\\riss.xls): ')

#Step 6.학위 논문 선택하기
driver.find_element(By.LINK_TEXT,telecomName).click()
time.sleep(2)

#Step 7.Beautiful Soup 로 본문 내용만 추출하기
from bs4 import BeautifulSoup
html_1 = driver.page_source
soup_1 = BeautifulSoup(html_1, 'html.parser')

content_1 = soup_1.find('div','srchResultListW').find_all('li')
for i in content_1 :
    print(i.get_text().replace("\n",""))

#Step 8. 총 검색 건수를 보여주고 수집할 건수 입력받기
import math
total_cnt = soup_1.find('div','searchBox').find('span','num').get_text()
print('검색하신 키워드 %s (으)로 총 %s 건의 학위논문이 검색되었습니다' %(query_txt,total_cnt))
collect_cnt = int(input('이 중에서 몇 건을 수집하시겠습니까?: '))
collect_page_cnt = math.ceil(collect_cnt / 10)
print('%s 건의 데이터를 수집하기 위해 %s 페이지의 게시물을 조회합니다.' %(collect_cnt,collect_page_cnt))
print('=' *80)
# Out:
# ====================================================================================================
#  이 크롤러는 RISS 사이트의 논문 및 학술자료 수집용 웹크롤러입니다.
# ====================================================================================================
# 1.수집할 자료의 키워드는 무엇입니까? : 해양자원
# 위 키워드로 아래의 장르 중 어떤 장르의 정보를 수집할까요?: .
#          1. 학위논문    2.국내학술논문    3.해외학술논문    4.학술지     5.단행본       6.공개강의      7.연구보고서
# 2
# 3.결과를 저장할 csv형식의 파일명을 쓰세요(예: c:\py_temp\riss.csv): 123
# 4.결과를 저장할 xls형식의 파일명을 쓰세요(예: c:\py_temp\riss.xls): 123
# 1발표논문 / 해양생물자원으로서 해조류 : 생물활성물질의 정제와 분자적 응용홍용기(Yong Ki Hong)한국조류학회2000국제심포지움 일정 및 발표논문집 - 21세기, 해양환경과 해양생물자원의 전망Vol.- No.-해조생물공학은 유용해조류 및 그들의 유용물질들을 경제적으로 생산할 수 있도록 개발하는 학문 분야이다. 본 논문에서는 이들 해조생물공학에 대한 실험방법적 접근을 강조하여 설명하고자 한다. 우선 해조류의 활력측정은 조직 자체의 효소활성 즉 무색의 2,3,5-triphenyltetrazolium chloride를 붉은색의 triphenylformazan으로 환원시키는 정도를 측정함으로서 정량적으로 간단하게 활력을 평가하는 방법을 확립하였다. 그리고 callus와 엽체 재생 등을 위한 무균 고체 조직배양에 가장 적합한 gelling agent들을 비교한바 high gel strength agar가 톳의 callus 형성 및 엽체 재생에 지지체로 가장 효율적이였다. 유용 생리활성물질의 탐색작업에서는 보라색우무 추출물에서 Taq DNA polymerase에 대한 저해작용을 보였으며, 청각, 구멍갈파래, 잎파래, 미역에는 Herpes simplex virus에 대한 항virus효과를 지녔다. 홑파래물추출물에서는 생먹이용 미세조류들의 성장에 촉진효과를 보였으며, 작은구슬산호말은 적조들의 성장을 억제시켰다. 넓패는 가시파래 및 담치에 대한 부착 억제작용을 보였다. 또한 김과 홑파래는 고cholesterol혈증에서 cholesterol수치를 강하시켰다.  그리고 해조류들의 유전분석을 위하여 DNA와 RNA 추출은 LiCl를 사용하여 간단하게 분리할수있다. 긴잎돌김, 여름김, 양식김 5종에 대한 18s rDNA 염기서열을 밝혔으며 RAPD 기법을 사용하여 지역간 톳 및 갈파래목의 유전적 다양성을 확인하였다. 김의 분화조직 들간 및 김의 산처리시 조직에서 반응을 나타내는 유전자들을 differential display 방법으로 분리하였다. 끝으로 김의 유전적 표식자를 gene gun을 사용하여 쉽게 김 엽체에 beta-glucuronidase gene을 도입할수 있었으며, 김의 품종 개량을 위하여 산 내성 및 필수 아미노산 고함유 품종을 선별중에 있다. Seaweed biotechnology is the field dealing with economical production of useful seaweeds and their chemicals. In this paper I will mainly discuss technical studies for the screening of biologically active substances and seaweed molecular characterization. At first, a seaweed viability assay was developed to evaluate tissue intactness using the enzymatic reduction of 2,3,5-triphenyltetrazolium chloride. Callus and blade formation, under axenic culture conditions of Hizikia fusiformis, depended on the selling agents used as a substrate. The most calli and blades were produced on solid media composed of 2% and 0.5% high gel strength agars, respectively. For biologically active substances from seaweed extracts, we have found a Taq DNA polymerase inhibitor, 2,3,6-tribromo-4,5-dihydroxyl benzyl methyl ether, from Symphyocladia latiuscula. Antiviral activity against Herpes simplex was detected from several seaweed extracts after light irradiation. Growth of feed phytoplanktons was enhanced by the addition of aqueous extract of the seaweed Monostroma nitidum. Algicidal activity of the seaweed Corallina pilulifera was detected against red tide microalgae. Antifouling activity of the Ishige folicea was detected against marine green algae and blue mussel. For the molecular characterization of seaweeds, DNA and RNA were extracted with the use of lithium chloride. The DNA was used as a template for PCR amplification to discriminate algae and for RAPD analysis. The RNA was of sufficient quality to be used as a cDNA template for differential display. We are now selecting acid-responding genes from the Porphyra yezoensis. Finally we have tried gene transfer into young P. yezoensis thalli by particle bombardment. Thalli, bombarded with tungsten particles coated with a beta-glucuronidase gene, showed a transient expression of the gene at 18.6 unit/mg/h. Selections of acid resistant stain and amino acid rich strain are going on for strain improvement of P. yezoensis.  Key words: biologically active substance, differential display, genetic analysis, seaweed, seaweed biotechnology
# 2수거된 해양폐기물 자원화 기술 개발(Ⅰ)길상인(Sang-In Keel),윤진한(Jin-Han Yun),최연석(Yeon-Seok Choi),강창구(Chang-Gu Kang),유정석(Jeong-Seok Yu)한국해양환경·에너지학회2002한국해양환경·에너지학회지Vol.5 No.2원문보기 3NDSLDBpiaDBpia본 연구는 수거된 해양폐기물을 원료로 이용하여 폐기물연료(RDF : Refuse Derived Fuel)를 제조하는 공정 개발을 목적으로 하고 있으며, 산업용 연료로서의 활용 가능성을 확인하기 제조된 RDF의 물성분석을 분석하였다. 해양폐기물은 로우프에서의 납제거와 파쇄 그리고 해저 슬러지의 세척과 같은 전처리, 그리고 가연성분의 입자화 공정을 통하여 해양폐기물이 에너지로 변환하는 것이 가능하게 되었다. 이와 같은 해양폐기물 자원화 공정은 수거 폐기물의 환경적 처리는 물론 대체에너지 확보의 측면에서 매우 유익한 것으로 사료된다. The purpose of this study is the RDF process development for the disposal of marine debris, and physical properties of RDF was analyzed for the reliability as a industrial fuel. By the separation of lead from the waste rope and the pelletizing of burning material, marine debris changes to fuel resources. The resource recycling process is effective in the clean treatment of waste and the secure of substitute energy.
# 원문보기 3NDSLDBpiaDBpia
# NDSL
# DBpia
# DBpia
# 3수거된 해양폐기물 자원화 기술 개발(Ⅱ)길상인(Sang-In Keel),김석준(Seock-Joon Kim),윤진한(Jin-Han Yun),강창구(Chang-Gu Kang),유정석(Jeong-Seok Yu)한국해양환경·에너지학회2002한국해양환경·에너지학회지Vol.5 No.2원문보기어구용 폐스티로폼을 자원으로 활용할 수 있도록 하기 위하여 세정과 건조공정을 도입하여 감용하는 장치를 자체 개발하였으며, 시스템을 폐스티로폼 발생 지자체에 설치하여 설비의 운전 신뢰성을 확인하였다. 굴피 및 홍합피 등의 이물질을 완벽하게 제거하고 해수에 포함된 염분을 육상에서 발생되는 스티로폼 수준까지 낮춤으로써 어구용 폐스티로폼은 플라스틱의 원료로 탈바꿈할 수 있었으며, 종래의 처리 방법에 비해 1/10수준에 불과한 비용으로 어구용 폐스티로폼의 처리가 가능하도록 함으로써 설비의 설치나 운영에 따르는 경제성 문제를 해결하고자 하였다. By the introduction of cleaning and drying processes, thermal extrusion system for the volume reduction of used polystyrene buoys was developed. It was tested in the costal area for the determination of operational reliability. By the removal of oyster shells and cleaning of salt, waste polystyrene buoys was changed to the raw material of plastics. The lower cost of one-tenth compared with that of the outer request treatment is promising the practical use of waste buoys' volume reduction system.
# 원문보기
# 4동아시아태평양 주요국가의 해양관리시스템 분석 : 해양질서관리와 해양자원관리를 중심으로주종광한국해양경찰학회2017한국해양경찰학회 학술대회Vol.2017 No.02원문보기
# 원문보기
# 5해양수산생명자원의 국내 접근 절차 관련 법제도의 문제점 및 개선방향 : 해양수산생명자원법과 유전자원법의 비교를 중심으로최석문,박수진해양환경안전학회2019해양환경안전학회 학술발표대회 논문집Vol.2019 No.11원문보기
# 원문보기
# 6우리나라 관할해역 내 해양자원 관리현황 및 정책 개선방향박수진(Su Jin Park)한국해양환경·에너지학회2014한국해양환경공학회 학술대회논문집Vol.2014 No.5원문보기
# 원문보기
# 7해양관광 활성화를 위한 해양문화관광자원 활용 방안 해양문화축제를 중심으로하경희(Ha, Kyoung-Hee)한국해양관광학회2018해양관광학연구Vol.11 No.1원문보기'스콜라' 이용 시 소속기관이 구독 중이 아닌 경우, 오후 4시부터 익일 오전 9시까지 원문보기가 가능합니다.Nowadays there are changes of types of tourism for experience tour and marine tour. And marine resources could satisfy the tourists  needs for software and contents of tour in the era of qualitative growth. Therefore this study is performed in order to propose the development directions of marine culture festivals for the sustainable tourism. The development directions of marine culture festivals are as follows. First, the development of the marine culture festivals should be considered the environmental and cultural value such as marine traditional culture and history. Second, the marine culture festivals programs should be focused on the educational contents on the basis of marine culture and environment. Third, regional brand strategy for marine cultural festivals is necessary with unique marine culture resources of region.
# 원문보기
# 8중국 해양자원개발의 해양강국 전략에 대한 함의주현희(Hyun-Hee Ju)한국해양비즈니스학회2014해양비즈니스Vol.- No.27원문보기'스콜라' 이용 시 소속기관이 구독 중이 아닌 경우, 오후 4시부터 익일 오전 9시까지 원문보기가 가능합니다.After “Reforming and Opening”, Chinese marine power strategy has been focusing on exploitation of marine resource. The goal of Chinese marine power strategy is to achieve domestic economic growth by developing ocean-based infrastructure including marine economy and promoting related industries. It is important for China to exploit and develop marine infrastructures which provide various strategic resources including foods, energy, minerals, water, and economic spaces in that the country lacks resources required for economic development.Success of Chinese marine power strategy may depend on how effectively they exploit and manage marine resources, as the share of Chinese marine industry has been consistently escalating. This study reviews the strategy of marine resources development strategy and provides implication and status of marine resources development to the marine power strategy in China.
# 원문보기
# 921세기 신성장동력원 해양유전자원의 개발박수진한국해양수산개발원2009해양국토21Vol.1 No.-원문보기
# 원문보기
# 10국가관할권 이원에서의 해양유전자원 개발에 관한 국제적 논의 동향김선화해양환경안전학회2012해양환경안전학회 학술발표대회 논문집Vol.2012 No.11원문보기
# 원문보기
# 검색하신 키워드 해양자원 (으)로 총 3,818 건의 학위논문이 검색되었습니다
# 이 중에서 몇 건을 수집하시겠습니까?: 25
# 25 건의 데이터를 수집하기 위해 3 페이지의 게시물을 조회합니다.
# ================================================================================

# %%
#Step 9. 각 항목별로 데이터를 추출하여 리스트에 저장하기
no2 = [ ]        #번호 저장
title2 = [ ]     #논문제목 저장
writer2 = [ ]    #논문저자 저장
org2 = [ ]       #소속기관 저장
year2=[ ]         #발표년도
house2=[ ]        #논문집/자료집
url_link2=[ ]     #url
no = 1

for a in range(1, collect_page_cnt + 1) :
    
    html_2 = driver.page_source
    soup_2 = BeautifulSoup(html_2, 'html.parser')

    content_2 = soup_2.find('div','srchResultListW').find_all('li')
    
    for b in content_2 :    
        #1. 논문제목 있을 경우만
        try :
            title = b.find('div','cont m160').find('p','title').get_text()
        except :
            continue
        else :
            f = open(ft_name, 'a' , encoding="UTF-8")
            print('1.번호:',no)
            no2.append(no)
            f.write('\n'+'1.번호:' + str(no))

            print('2.논문제목:',title)
            title2.append(title)
            f.write('\n' + '2.논문제목:' + title)
            
            writer = b.find('span','writer').get_text()
            print('3.저자:',writer)
            writer2.append(writer)
            f.write('\n' + '3.저자:' + writer)

            org = b.find('span','assigned').get_text()
            print('4.소속기관:' , org)
            org2.append(org)
            f.write('\n' + '4.소속기관:' + org)
            
            year = b.find('span','assigned').get_text()
            print('5.발표년도:' , year)
            year2.append(org)
            f.write('\n' + '5.발표년도:' + year)
            
            house = b.find('span','assigned').get_text()
            print('6.논문집/자료집:' , house)
            house2.append(house)
            f.write('\n' + '6.논문집/자료집:' + house)
            
            url_link = b.find('span','assigned').get_text()
            print('7.논문 URL 주소:' , url_link)
            url_link2.append(url_link)
            f.write('\n' + '7.논문 URL 주소:' + url_link)
            
            f.close( )
            
            no += 1
            print("\n")
            
            if no > collect_cnt :
                break

            time.sleep(1)        # 페이지 변경 전 1초 대기 

    a += 1 
    b = str(a)

    try :
        driver.find_element(By.LINK_TEXT ,'%s' %b).click() 
    except :
        driver.find_element(By.LINK_TEXT('다음 페이지로')).click()
        
print("요청하신 작업이 모두 완료되었습니다")
# Out:
# 요청하신 작업이 모두 완료되었습니다

# %%
type(writer2)
# Out:
# list

# %%
# Step 10. 수집된 데이터를 xls와 csv 형태로 저장하기
import pandas as pd 

df = pd.DataFrame()
df['번호']=no2
df['제목']=pd.Series(title2)
df['저자']=pd.Series(writer2)
df['소속(발행)기관']=pd.Series(org2)

# xls 형태로 저장하기
df.to_excel(fx_name,index=False, encoding="utf-8" , engine='openpyxl')

# csv 형태로 저장하기
df.to_csv(fc_name,index=False, encoding="utf-8-sig")

print('요청하신 데이터 수집 작업이 정상적으로 완료되었습니다')
# Out:
# ====================================================================================================
#  이 크롤러는 RISS 사이트의 논문 및 학술자료 수집용 웹크롤러입니다.
# ====================================================================================================
# 1.수집할 자료의 키워드는 무엇입니까? : 해양자원
# 위 키워드로 아래의 장르 중 어떤 장르의 정보를 수집할까요?: .
#          1. 학위논문    2.국내학술논문    3.해외학술논문    4.학술지     5.단행본       6.공개강의      7.연구보고서
# 2
# 3.결과를 저장할 csv형식의 파일명을 쓰세요(예: c:\py_temp\riss.csv): c:\py_temp\riss.csv
# 4.결과를 저장할 xls형식의 파일명을 쓰세요(예: c:\py_temp\riss.xls): c:\py_temp\riss.xls
# 1발표논문 / 해양생물자원으로서 해조류 : 생물활성물질의 정제와 분자적 응용홍용기(Yong Ki Hong)한국조류학회2000국제심포지움 일정 및 발표논문집 - 21세기, 해양환경과 해양생물자원의 전망Vol.- No.-해조생물공학은 유용해조류 및 그들의 유용물질들을 경제적으로 생산할 수 있도록 개발하는 학문 분야이다. 본 논문에서는 이들 해조생물공학에 대한 실험방법적 접근을 강조하여 설명하고자 한다. 우선 해조류의 활력측정은 조직 자체의 효소활성 즉 무색의 2,3,5-triphenyltetrazolium chloride를 붉은색의 triphenylformazan으로 환원시키는 정도를 측정함으로서 정량적으로 간단하게 활력을 평가하는 방법을 확립하였다. 그리고 callus와 엽체 재생 등을 위한 무균 고체 조직배양에 가장 적합한 gelling agent들을 비교한바 high gel strength agar가 톳의 callus 형성 및 엽체 재생에 지지체로 가장 효율적이였다. 유용 생리활성물질의 탐색작업에서는 보라색우무 추출물에서 Taq DNA polymerase에 대한 저해작용을 보였으며, 청각, 구멍갈파래, 잎파래, 미역에는 Herpes simplex virus에 대한 항virus효과를 지녔다. 홑파래물추출물에서는 생먹이용 미세조류들의 성장에 촉진효과를 보였으며, 작은구슬산호말은 적조들의 성장을 억제시켰다. 넓패는 가시파래 및 담치에 대한 부착 억제작용을 보였다. 또한 김과 홑파래는 고cholesterol혈증에서 cholesterol수치를 강하시켰다.  그리고 해조류들의 유전분석을 위하여 DNA와 RNA 추출은 LiCl를 사용하여 간단하게 분리할수있다. 긴잎돌김, 여름김, 양식김 5종에 대한 18s rDNA 염기서열을 밝혔으며 RAPD 기법을 사용하여 지역간 톳 및 갈파래목의 유전적 다양성을 확인하였다. 김의 분화조직 들간 및 김의 산처리시 조직에서 반응을 나타내는 유전자들을 differential display 방법으로 분리하였다. 끝으로 김의 유전적 표식자를 gene gun을 사용하여 쉽게 김 엽체에 beta-glucuronidase gene을 도입할수 있었으며, 김의 품종 개량을 위하여 산 내성 및 필수 아미노산 고함유 품종을 선별중에 있다. Seaweed biotechnology is the field dealing with economical production of useful seaweeds and their chemicals. In this paper I will mainly discuss technical studies for the screening of biologically active substances and seaweed molecular characterization. At first, a seaweed viability assay was developed to evaluate tissue intactness using the enzymatic reduction of 2,3,5-triphenyltetrazolium chloride. Callus and blade formation, under axenic culture conditions of Hizikia fusiformis, depended on the selling agents used as a substrate. The most calli and blades were produced on solid media composed of 2% and 0.5% high gel strength agars, respectively. For biologically active substances from seaweed extracts, we have found a Taq DNA polymerase inhibitor, 2,3,6-tribromo-4,5-dihydroxyl benzyl methyl ether, from Symphyocladia latiuscula. Antiviral activity against Herpes simplex was detected from several seaweed extracts after light irradiation. Growth of feed phytoplanktons was enhanced by the addition of aqueous extract of the seaweed Monostroma nitidum. Algicidal activity of the seaweed Corallina pilulifera was detected against red tide microalgae. Antifouling activity of the Ishige folicea was detected against marine green algae and blue mussel. For the molecular characterization of seaweeds, DNA and RNA were extracted with the use of lithium chloride. The DNA was used as a template for PCR amplification to discriminate algae and for RAPD analysis. The RNA was of sufficient quality to be used as a cDNA template for differential display. We are now selecting acid-responding genes from the Porphyra yezoensis. Finally we have tried gene transfer into young P. yezoensis thalli by particle bombardment. Thalli, bombarded with tungsten particles coated with a beta-glucuronidase gene, showed a transient expression of the gene at 18.6 unit/mg/h. Selections of acid resistant stain and amino acid rich strain are going on for strain improvement of P. yezoensis.  Key words: biologically active substance, differential display, genetic analysis, seaweed, seaweed biotechnology
# 2수거된 해양폐기물 자원화 기술 개발(Ⅰ)길상인(Sang-In Keel),윤진한(Jin-Han Yun),최연석(Yeon-Seok Choi),강창구(Chang-Gu Kang),유정석(Jeong-Seok Yu)한국해양환경·에너지학회2002한국해양환경·에너지학회지Vol.5 No.2원문보기 3NDSLDBpiaDBpia본 연구는 수거된 해양폐기물을 원료로 이용하여 폐기물연료(RDF : Refuse Derived Fuel)를 제조하는 공정 개발을 목적으로 하고 있으며, 산업용 연료로서의 활용 가능성을 확인하기 제조된 RDF의 물성분석을 분석하였다. 해양폐기물은 로우프에서의 납제거와 파쇄 그리고 해저 슬러지의 세척과 같은 전처리, 그리고 가연성분의 입자화 공정을 통하여 해양폐기물이 에너지로 변환하는 것이 가능하게 되었다. 이와 같은 해양폐기물 자원화 공정은 수거 폐기물의 환경적 처리는 물론 대체에너지 확보의 측면에서 매우 유익한 것으로 사료된다. The purpose of this study is the RDF process development for the disposal of marine debris, and physical properties of RDF was analyzed for the reliability as a industrial fuel. By the separation of lead from the waste rope and the pelletizing of burning material, marine debris changes to fuel resources. The resource recycling process is effective in the clean treatment of waste and the secure of substitute energy.
# 원문보기 3NDSLDBpiaDBpia
# NDSL
# DBpia
# DBpia
# 3수거된 해양폐기물 자원화 기술 개발(Ⅱ)길상인(Sang-In Keel),김석준(Seock-Joon Kim),윤진한(Jin-Han Yun),강창구(Chang-Gu Kang),유정석(Jeong-Seok Yu)한국해양환경·에너지학회2002한국해양환경·에너지학회지Vol.5 No.2원문보기어구용 폐스티로폼을 자원으로 활용할 수 있도록 하기 위하여 세정과 건조공정을 도입하여 감용하는 장치를 자체 개발하였으며, 시스템을 폐스티로폼 발생 지자체에 설치하여 설비의 운전 신뢰성을 확인하였다. 굴피 및 홍합피 등의 이물질을 완벽하게 제거하고 해수에 포함된 염분을 육상에서 발생되는 스티로폼 수준까지 낮춤으로써 어구용 폐스티로폼은 플라스틱의 원료로 탈바꿈할 수 있었으며, 종래의 처리 방법에 비해 1/10수준에 불과한 비용으로 어구용 폐스티로폼의 처리가 가능하도록 함으로써 설비의 설치나 운영에 따르는 경제성 문제를 해결하고자 하였다. By the introduction of cleaning and drying processes, thermal extrusion system for the volume reduction of used polystyrene buoys was developed. It was tested in the costal area for the determination of operational reliability. By the removal of oyster shells and cleaning of salt, waste polystyrene buoys was changed to the raw material of plastics. The lower cost of one-tenth compared with that of the outer request treatment is promising the practical use of waste buoys' volume reduction system.
# 원문보기
# 4동아시아태평양 주요국가의 해양관리시스템 분석 : 해양질서관리와 해양자원관리를 중심으로주종광한국해양경찰학회2017한국해양경찰학회 학술대회Vol.2017 No.02원문보기
# 원문보기
# 5해양수산생명자원의 국내 접근 절차 관련 법제도의 문제점 및 개선방향 : 해양수산생명자원법과 유전자원법의 비교를 중심으로최석문,박수진해양환경안전학회2019해양환경안전학회 학술발표대회 논문집Vol.2019 No.11원문보기
# 원문보기
# 6우리나라 관할해역 내 해양자원 관리현황 및 정책 개선방향박수진(Su Jin Park)한국해양환경·에너지학회2014한국해양환경공학회 학술대회논문집Vol.2014 No.5원문보기
# 원문보기
# 7해양관광 활성화를 위한 해양문화관광자원 활용 방안 해양문화축제를 중심으로하경희(Ha, Kyoung-Hee)한국해양관광학회2018해양관광학연구Vol.11 No.1원문보기'스콜라' 이용 시 소속기관이 구독 중이 아닌 경우, 오후 4시부터 익일 오전 9시까지 원문보기가 가능합니다.Nowadays there are changes of types of tourism for experience tour and marine tour. And marine resources could satisfy the tourists  needs for software and contents of tour in the era of qualitative growth. Therefore this study is performed in order to propose the development directions of marine culture festivals for the sustainable tourism. The development directions of marine culture festivals are as follows. First, the development of the marine culture festivals should be considered the environmental and cultural value such as marine traditional culture and history. Second, the marine culture festivals programs should be focused on the educational contents on the basis of marine culture and environment. Third, regional brand strategy for marine cultural festivals is necessary with unique marine culture resources of region.
# 원문보기
# 8중국 해양자원개발의 해양강국 전략에 대한 함의주현희(Hyun-Hee Ju)한국해양비즈니스학회2014해양비즈니스Vol.- No.27원문보기'스콜라' 이용 시 소속기관이 구독 중이 아닌 경우, 오후 4시부터 익일 오전 9시까지 원문보기가 가능합니다.After “Reforming and Opening”, Chinese marine power strategy has been focusing on exploitation of marine resource. The goal of Chinese marine power strategy is to achieve domestic economic growth by developing ocean-based infrastructure including marine economy and promoting related industries. It is important for China to exploit and develop marine infrastructures which provide various strategic resources including foods, energy, minerals, water, and economic spaces in that the country lacks resources required for economic development.Success of Chinese marine power strategy may depend on how effectively they exploit and manage marine resources, as the share of Chinese marine industry has been consistently escalating. This study reviews the strategy of marine resources development strategy and provides implication and status of marine resources development to the marine power strategy in China.
# 원문보기
# 921세기 신성장동력원 해양유전자원의 개발박수진한국해양수산개발원2009해양국토21Vol.1 No.-원문보기
# 원문보기
# 10국가관할권 이원에서의 해양유전자원 개발에 관한 국제적 논의 동향김선화해양환경안전학회2012해양환경안전학회 학술발표대회 논문집Vol.2012 No.11원문보기
# 원문보기
# 검색하신 키워드 해양자원 (으)로 총 3,818 건의 학위논문이 검색되었습니다
# 이 중에서 몇 건을 수집하시겠습니까?: 25
# 25 건의 데이터를 수집하기 위해 3 페이지의 게시물을 조회합니다.
# ================================================================================
# 요청하신 작업이 모두 완료되었습니다
# 요청하신 데이터 수집 작업이 정상적으로 완료되었습니다
# C:\Users\jmjun\AppData\Local\Temp\ipykernel_18212\935413445.py:166: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df['제목']=pd.Series(title2)
# C:\Users\jmjun\AppData\Local\Temp\ipykernel_18212\935413445.py:167: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df['저자']=pd.Series(writer2)
# C:\Users\jmjun\AppData\Local\Temp\ipykernel_18212\935413445.py:168: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df['소속(발행)기관']=pd.Series(org2)

# %% [markdown]
# # 상세정보 수집 후 다양한 형식의 파일로 저장하기
