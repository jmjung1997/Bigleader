# %% [markdown]
# # 빈도분석 연습문제

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import pandas as pd
news_data=pd.read_csv('/content/gdrive/MyDrive/pytest/뉴스데이터.csv',encoding="utf-8")

# %%
news_data
# Out:
#           id        날짜            분류1       분류2  \
# 0      77369  20180619          지역,광주     지역,전남
# 1      77370  20180619          지역,광주     지역,전남
# 2      77371  20180619          지역,광주     지역,전남
# 3      77372  20180619          지역,광주     지역,전남
# 4      77378  20180619          지역,광주     지역,전남
# ...      ...       ...            ...       ...
# 9052  545182  20181013         사회,미디어       NaN
# 9053  545620  20181013          지역,광주     지역,전남
# 9054  545622  20181013          지역,광주     지역,전남
# 9055  545654  20181013         국제,아시아  국제,유럽_EU
# 9056  545710  20181013  스포츠,올림픽_아시안게임       NaN
#
#                                                     텍스트
# 0     하늘길 운항노선도 광주-제주 광주-양양 광주-김해 등 국내는 물론 일본과 중국 등 ...
# 1     저가항공보다는 프레미엄 비즈니스 전문 항공사를 추구하는 에어필립은 지방 도시간 항공...
# 2     울릉도와 흑산도 등의 소형공항이 수년 내 문을 열 경우 광주․전남 지역민의 관광 접...
# 3     지역민들이 해외여행을 위해 인천공항에 갈 때마다 고속버스에 ‘수화물’을 싣고 내리던...
# 4     포항출신인 필립에셋 엄일석 회장은 “광주에 18년 동안 살면서 강원도나 인천공항에 ...
# ...

# %%
news_data.isnull().values.any()
# Out:
# True

# %%
news_data.isnull().sum()
# Out:
# id        0
# 날짜        0
# 분류1       0
# 분류2    2734
# 텍스트       0
# dtype: int64

# %%
news_data=news_data.dropna(subset=['분류2'])

# %%
news_data.isnull().sum()
# Out:
# id     0
# 날짜     0
# 분류1    0
# 분류2    0
# 텍스트    0
# dtype: int64

# %%
data1=news_data.drop(columns=["분류2"])

# %%
data1.columns
# Out:
# Index(['id', '날짜', '분류1', '텍스트'], dtype='object')

# %%
data2=news_data.drop(columns=["분류1"])

# %%
from collections import Counter

# %%
# !apt-get update
# !apt-get install g++ openjdk-8-jdk
# !pip install JPype1
# !pip install rhinoMorph
# Out:
# Hit:1 http://archive.ubuntu.com/ubuntu bionic InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Hit:4 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease
# Get:5 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Hit:6 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Ign:7 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Get:8 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Hit:9 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:10 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Hit:11 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Hit:12 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# ...

# %%
def read_data(filename, encoding='cp949'):
  with open(filename, 'r', encoding=encoding) as f:
    data = [line.split('\t') for line in f.read().splitlines()]
  return data

def write_data(data, filename, encoding='cp949'):
  with open(filename, 'w', encoding=encoding) as f:
    f.write(data)

# %%
import rhinoMorph
rn=rhinoMorph.startRhino()
# Out:
# filepath:  /usr/local/lib/python3.7/dist-packages
# classpath:  /usr/local/lib/python3.7/dist-packages/rhinoMorph/lib/rhino.jar
# RHINO started!

# %%
# news_morphed_data=''
# for data_each in data:
#   news_morphed_data_each=rhinoMorph.onlyMorph_list(rn, data_each[0], pos=['NNG', 'NNP', 'NP', 'VV', 'VA', 'VX', 'XR', 'IC', 'MM', 'MAG'])
#   print("news_morphed_data_each: ", news_morphed_data_each)
#   joined_data_each=' '.join(news_morphed_data_each)
#   if joined_data_each:
#     news_morphed_data+=joined_data_each+'\t'+data_each[1]+'\n'
# print('Morphological Analysis Completed.')

# write_data(morphed_data, chat_dir+'chat_morphed.txt', encoding='cp949')

# %%
len(news_data)
# Out:
# 6323

# %%
toplist = []
bottomlist = []
for region in data1['분류1']:
  region_split = region.split(',')
  toplist.append(region_split[0])

toplist=list(set(toplist))# set은 중복된 값을 날리기 위해

# %%
toplist
# Out:
# ['사회', '문화', '경제', '국제', '지역', '스포츠', 'IT_과학']

# %%
path='/content/gdrive/MyDrive/pytest/data/'
data1.to_csv(path+'data1.txt',sep='\t')
data1 = read_data(path+'data1.txt',encoding='utf-8') #위에 속성줄 떼고 부르기
print(len(data1))
print(len(data1[0]))
print(data1[1:3])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-e9aeb552584d> in <module>()
#       1 path='/content/gdrive/MyDrive/pytest/data/'
# ----> 2 data1.to_csv(path+'data1.txt',sep='\t')
#       3 data1 = read_data(path+'data1.txt',encoding='utf-8') #위에 속성줄 떼고 부르기
#       4 print(len(data1))
#       5 print(len(data1[0]))
#
# AttributeError: 'list' object has no attribute 'to_csv'
