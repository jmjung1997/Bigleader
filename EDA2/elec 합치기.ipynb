# %%
import numpy as np
import pandas as pd

# %%
data_elec=pd.read_excel('./data/extra/elec_use.xlsx' )

data_elec.head()
# Out:
#   STDR_YM CTPRVN_NM SIGNGU_NM INDUTY_MLSFC_NM  elec_use
# 0  2015-1     서울특별시       종로구          농업. 임업    6041.0
# 1  2015-2     서울특별시       종로구          농업. 임업    7555.0
# 2  2015-3     서울특별시       종로구          농업. 임업    5420.0
# 3  2015-4     서울특별시       종로구          농업. 임업    4821.0
# 4  2015-5     서울특별시       종로구          농업. 임업    4090.0

# %%
data_elec = data_elec.groupby(['STDR_YM','CTPRVN_NM','SIGNGU_NM'],as_index=False).sum()

# %%
data_elec.head(50)
# Out:
#    STDR_YM CTPRVN_NM SIGNGU_NM      elec_use
# 0   2015-1       강원도       강릉시  1.824080e+08
# 1   2015-1       강원도       고성군  3.002259e+07
# 2   2015-1       강원도       동해시  2.575040e+08
# 3   2015-1       강원도       삼척시  1.104547e+08
# 4   2015-1       강원도       속초시  4.676312e+07
# 5   2015-1       강원도       양구군  2.528230e+07
# 6   2015-1       강원도       양양군  2.805044e+07
# 7   2015-1       강원도       영월군  8.541796e+07
# 8   2015-1       강원도       원주시  2.417811e+08
# 9   2015-1       강원도       인제군  3.745719e+07
# 10  2015-1       강원도       정선군  6.485483e+07
# 11  2015-1       강원도       철원군  5.528152e+07
# 12  2015-1       강원도       춘천시  1.694978e+08
# 13  2015-1       강원도       태백시  3.415235e+07
# 14  2015-1       강원도       평창군  7.439205e+07
# 15  2015-1       강원도       홍천군  7.915957e+07
# 16  2015-1       강원도       화천군  2.929084e+07
# 17  2015-1       강원도       횡성군  6.525891e+07
# 18  2015-1       경기도       가평군  7.542506e+07
# 19  2015-1       경기도       고양시  4.568280e+08
# ...

# %%
data_elec['STDR_YM'] = pd.to_datetime(data_elec['STDR_YM'])

# %%
data_elec
# Out:
#          STDR_YM CTPRVN_NM SIGNGU_NM     elec_use
# 0     2015-01-01       강원도       강릉시  182407990.0
# 1     2015-01-01       강원도       고성군   30022592.0
# 2     2015-01-01       강원도       동해시  257503954.0
# 3     2015-01-01       강원도       삼척시  110454730.0
# 4     2015-01-01       강원도       속초시   46763124.0
# ...          ...       ...       ...          ...
# 22027 2022-09-01      충청북도       제천시          0.0
# 22028 2022-09-01      충청북도       증평군          0.0
# 22029 2022-09-01      충청북도       진천군          0.0
# 22030 2022-09-01      충청북도       청주시          0.0
# 22031 2022-09-01      충청북도       충주시          0.0
#
# [22032 rows x 4 columns]

# %%
data_elec['STDR_YM']=data_elec['STDR_YM'].dt.strftime('%Y-%m')

# %%
data_elec
# Out:
#        STDR_YM CTPRVN_NM SIGNGU_NM     elec_use
# 0      2015-01       강원도       강릉시  182407990.0
# 1      2015-01       강원도       고성군   30022592.0
# 2      2015-01       강원도       동해시  257503954.0
# 3      2015-01       강원도       삼척시  110454730.0
# 4      2015-01       강원도       속초시   46763124.0
# ...        ...       ...       ...          ...
# 22027  2022-09      충청북도       제천시          0.0
# 22028  2022-09      충청북도       증평군          0.0
# 22029  2022-09      충청북도       진천군          0.0
# 22030  2022-09      충청북도       청주시          0.0
# 22031  2022-09      충청북도       충주시          0.0
#
# [22032 rows x 4 columns]

# %%
data_elec = data_elec.groupby(['STDR_YM','CTPRVN_NM','SIGNGU_NM'], as_index=False).sum()

# %%
data_elec.isna().sum()
# Out:
# STDR_YM      0
# CTPRVN_NM    0
# SIGNGU_NM    0
# elec_use     0
# dtype: int64

# %%
data_elec[data_elec['SIGNGU_NM']=='미추홀구']
# Out:
#        STDR_YM CTPRVN_NM SIGNGU_NM     elec_use
# 159    2015-01     인천광역시      미추홀구  201785089.0
# 389    2015-02     인천광역시      미추홀구  185605823.0
# 619    2015-03     인천광역시      미추홀구  179908984.0
# 849    2015-04     인천광역시      미추홀구  185901383.0
# 1079   2015-05     인천광역시      미추홀구  158826023.0
# ...        ...       ...       ...          ...
# 21046  2022-08     인천광역시      미추홀구          0.0
# 21275  2022-09     인천광역시      미추홀구          0.0
# 21504  2022-10     인천광역시      미추홀구          0.0
# 21733  2022-11     인천광역시      미추홀구          0.0
# 21962  2022-12     인천광역시      미추홀구          0.0
#
# [96 rows x 4 columns]

# %%
data_elec.to_excel('Use_elec.xlsx',index=False)
