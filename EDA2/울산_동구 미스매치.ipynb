# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime
one_data=pd.read_excel('./data/total/dataset.xlsx')

# %%
jikjong=pd.read_excel('./data/mismatch/유효구인구직현황(직종별)_1661326896792.xlsx')
goyongtype=pd.read_excel('./data/mismatch/유효구인구직현황(고용형태별)_1661325417303.xlsx')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
one_data_dg=one_data[(one_data['CTPRVN_NM']=='울산광역시')&(one_data['SIGNGU_NM']=='동구')]

one_data_dg.head()

pd.set_option('display.max_columns', None)

pd.set_option('display.max_rows', None)

import os
import os.path

pd.set_option('display.max_columns', None)

pd.set_option('display.max_rows', None)

from matplotlib import font_manager, rc

font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

one_data_dg.to_csv('./data/one_data_dg.csv',encoding="utf-8-sig",index=False)

# %matplotlib inline

columns=one_data_dg.columns

columns

for i in one_data_dg.columns:
    y1=one_data_dg[str(i)]
    x=one_data_dg['STDR_YM']
    fig,ax1 = plt.subplots(figsize=(20,10))
    ax=ax1.plot(x, y1, color = '#c02ad1', alpha = 0.5,label=i,linestyle='solid', linewidth=3)
    plt.legend(loc='upper left')
    plt.xlabel("시간")
    plt.ylabel("Data")
    plt.xticks(rotation=45) 
    plt.grid(False)
    plt.tight_layout()        
    plt.savefig('./미스매치 결과/'+str(i)+'.png',facecolor='#eeeeee',edgecolor='black',format='png', dpi=100,box_inches='tight',pad_inches=4)

### 유효구인 구직(정규직 비정규직)

goyongtype.시군구

goyongtype['STDR_YM'].fillna(method='ffill', inplace=True)
goyongtype['시군구'].fillna(method='ffill', inplace=True)

goyongtype.head()

split = goyongtype.시군구.str.split()
split = split.apply(lambda x: pd.Series(x))
split

tmp = pd.concat([goyongtype, split], axis=1)

tmp

colnames = list(tmp.columns)
colnames[5:] = ['시도명','시군구명']
tmp.columns = colnames
tmp

tmp.drop('시군구' , axis=1, inplace=True)

tmp.columns

goyongtype_final = tmp[['STDR_YM', '시도명','시군구명','고용형태','유효구인인원','유효구직자수']]

goyongtype_final

goyongtype_final.columns = ['STDR_YM','CTPRVN_NM','SIGNGU_NM','고용형태','유효구인인원','유효구직자수']

goyongtype_final

goyongtype_final_dongu=goyongtype_final[goyongtype_final['SIGNGU_NM']=='동구']

goyongtype_final_dongu.reset_index(drop=True)

goyongtype_final_dongu.to_csv('./data/mismatch/goyongtype_final_dongu.csv',index=False)

# %% [markdown]
# ### 구인 구직 직종별

# %%
guin=pd.read_excel('./data/mismatch/구인구직 최종.xlsx')

# %%
guin.head()
# Out:
#      STDR_YM       시군구      직종_중분류                      고용형태  유효구인인원  유효구직자수
# 0  2015년 01월  울산광역시 중구  2007직종_관리직           기간의 정함이 없는 근로계약      12     161
# 1        NaN       NaN         NaN  기간의 정함이 없는 근로계약(시간(선택)제)       0       5
# 2        NaN       NaN         NaN           기간의 정함이 있는 근로계약       1      19
# 3        NaN       NaN         NaN  기간의 정함이 있는 근로계약(시간(선택)제)       0       3
# 4        NaN       NaN         NaN                      관계없음       0      71

# %%
guin['STDR_YM'].fillna(method='ffill', inplace=True)
guin['시군구'].fillna(method='ffill', inplace=True)
guin['직종_중분류'].fillna(method='ffill', inplace=True)

guin.head()

split = guin.시군구.str.split()
split = split.apply(lambda x: pd.Series(x))
split.head()

tmp = pd.concat([guin, split], axis=1)

tmp.head()

colnames = list(tmp.columns)
colnames[6:] = ['시도명','시군구명']
tmp.columns = colnames
tmp.head()

tmp.drop('시군구' , axis=1, inplace=True)

tmp.columns

guin = tmp[['STDR_YM', '시도명','시군구명','직종_중분류','고용형태','유효구인인원','유효구직자수']]

guin.tail()

# %%
for i in range(2007,2019):
    print(i)
    guin['직종_중분류']=guin['직종_중분류'].str.replace(str(i),'')
# Out:
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2018

# %%
guin.tail()
# Out:
#          STDR_YM    시도명 시군구명 직종_중분류                      고용형태  유효구인인원  유효구직자수
# 62860  2022년 05월  울산광역시  울주군  농림어업직  기간의 정함이 없는 근로계약(시간(선택)제)       5       1
# 62861  2022년 05월  울산광역시  울주군  농림어업직           기간의 정함이 있는 근로계약       1       8
# 62862  2022년 05월  울산광역시  울주군  농림어업직  기간의 정함이 있는 근로계약(시간(선택)제)       0       2
# 62863  2022년 05월  울산광역시  울주군  농림어업직                       일용직       0       8
# 62864  2022년 05월  울산광역시  울주군  농림어업직                      관계없음       0      35

# %%
guin['직종_중분류']=guin['직종_중분류'].str.replace('직종_','')

# %%
guin_donngu=guin[guin['시군구명']=='동구']

# %%
guin_donngu.reset_index(drop=True, inplace=True)
guin_donngu.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [15], in <cell line: 1>()
# ----> 1 guin_donngu.reset_index(drop=True, inplace=True)
#       2 guin_donngu.head()
#
# NameError: name 'guin_donngu' is not defined

# %%
guin_donngu.to_csv('./data/mismatch/guin_donngu_중분류까지.csv',index=False)

# %% [markdown]
# ### 울산 동구 직종별 구인 구직 분석

# %%
donngu=pd.read_csv('./data/mismatch/guin_donngu_중분류까지.csv',encoding='utf-8')

# %%
donngu.head()
# Out:
#      STDR_YM    시도명 시군구명        직종_중분류                      고용형태  유효구인인원  \
# 0  2015년 01월  울산광역시   동구           관리직           기간의 정함이 없는 근로계약       5
# 1  2015년 01월  울산광역시   동구           관리직  기간의 정함이 없는 근로계약(시간(선택)제)       0
# 2  2015년 01월  울산광역시   동구           관리직           기간의 정함이 있는 근로계약       1
# 3  2015년 01월  울산광역시   동구           관리직                      관계없음       0
# 4  2015년 01월  울산광역시   동구  경영·회계·사무 관련직           기간의 정함이 없는 근로계약      26
#
#    유효구직자수
# 0      60
# 1       5
# 2       6
# 3      19
# 4     539

# %%
donngu['직종_중분류'].unique()
# Out:
# array(['관리직', '경영·회계·사무 관련직', '금융·보험 관련직', '교육 및 자연과학·사회과학 연구 관련직',
#        '법률·경찰·소방·교도 관련직', '보건·의료 관련직', '사회복지 및 종교 관련직',
#        '문화·예술·디자인·방송 관련직', '운전 및 운송 관련직', '영업 및 판매 관련직', '경비 및 청소 관련직',
#        '미용·숙박·여행·오락 및 스포츠 관련직', '음식서비스 관련직', '건설 관련직', '기계 관련직',
#        '재료 관련직(금속·유리·점토 및 시멘트)', '화학 관련직', '섬유 및 의복 관련직', '전기·전자 관련직',
#        '정보통신 관련직', '식품가공 관련직', '환경·인쇄·목재·가구·공예 및 생산 단순직', '농림어업 관련직',
#        '군인', '관리직(임원·부서장)', '경영·행정·사무직', '금융·보험직', '자연·생명과학 연구직',
#        '정보통신 연구개발직 및 공학기술직', '건설·채굴 연구개발직 및 공학기술직', '제조 연구개발직 및 공학기술직',
#        '교육직', '법률직', '사회복지·종교직', '경찰·소방·교도직', '보건·의료직', '예술·디자인·방송직',
#        '스포츠·레크리에이션직', '미용·예식 서비스직', '여행·숙박·오락 서비스직', '음식 서비스직', '경호·경비직',
#        '돌봄 서비스직(간병·육아)', '청소 및 기타 개인서비스직', '영업·판매직', '운전·운송직', '건설·채굴직',
#        '기계 설치·정비·생산직', '금속·재료 설치·정비·생산직(판금·단조·주조·용접·도장 등)',
#        '전기·전자 설치·정비·생산직', '정보통신 설치·정비직', '화학·환경 설치·정비·생산직', '섬유·의복 생산직',
#        '식품가공·생산직', '인쇄·목재·공예 및 기타 설치·정비·생산직', '제조 단순직', '농림어업직',
# ...

# %%
donngu['직종_중분류']=donngu['직종_중분류'].str.replace('재료 관련직\(금속·유리·점토 및 시멘트\)','금속·재료 설치·정비·생산직(판금·단조·주조·용접·도장 등)')
# Out:
# C:\Users\jmjun\AppData\Local\Temp\ipykernel_5364\4162364960.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   donngu['직종_중분류']=donngu['직종_중분류'].str.replace('재료 관련직\(금속·유리·점토 및 시멘트\)','금속·재료 설치·정비·생산직(판금·단조·주조·용접·도장 등)')

# %%
dongu_mid=donngu[donngu['직종_중분류']=='금속·재료 설치·정비·생산직(판금·단조·주조·용접·도장 등)']

# %%
dongu_mid.head()
# Out:
#       STDR_YM    시도명 시군구명                             직종_중분류  \
# 71  2015년 01월  울산광역시   동구  금속·재료 설치·정비·생산직(판금·단조·주조·용접·도장 등)
# 72  2015년 01월  울산광역시   동구  금속·재료 설치·정비·생산직(판금·단조·주조·용접·도장 등)
# 73  2015년 01월  울산광역시   동구  금속·재료 설치·정비·생산직(판금·단조·주조·용접·도장 등)
# 74  2015년 01월  울산광역시   동구  금속·재료 설치·정비·생산직(판금·단조·주조·용접·도장 등)
# 75  2015년 01월  울산광역시   동구  금속·재료 설치·정비·생산직(판금·단조·주조·용접·도장 등)
#
#                         고용형태  유효구인인원  유효구직자수
# 71           기간의 정함이 없는 근로계약     427     201
# 72  기간의 정함이 없는 근로계약(시간(선택)제)       5       4
# 73           기간의 정함이 있는 근로계약      20      18
# 74  기간의 정함이 있는 근로계약(시간(선택)제)       5       2
# 75                      관계없음       0      76

# %%
dongu_mid.reset_index(drop=True, inplace=True)
dongu_mid.head()
# Out:
#      STDR_YM    시도명 시군구명                             직종_중분류  \
# 0  2015년 01월  울산광역시   동구  금속·재료 설치·정비·생산직(판금·단조·주조·용접·도장 등)
# 1  2015년 01월  울산광역시   동구  금속·재료 설치·정비·생산직(판금·단조·주조·용접·도장 등)
# 2  2015년 01월  울산광역시   동구  금속·재료 설치·정비·생산직(판금·단조·주조·용접·도장 등)
# 3  2015년 01월  울산광역시   동구  금속·재료 설치·정비·생산직(판금·단조·주조·용접·도장 등)
# 4  2015년 01월  울산광역시   동구  금속·재료 설치·정비·생산직(판금·단조·주조·용접·도장 등)
#
#                        고용형태  유효구인인원  유효구직자수
# 0           기간의 정함이 없는 근로계약     427     201
# 1  기간의 정함이 없는 근로계약(시간(선택)제)       5       4
# 2           기간의 정함이 있는 근로계약      20      18
# 3  기간의 정함이 있는 근로계약(시간(선택)제)       5       2
# 4                      관계없음       0      76

# %%
dongu_mid.to_csv('./data/mismatch/dongu_mid_동구 한정 용접.csv',index=False)

# %% [markdown]
# ### 울산 동구 직종별 나이별 피보험자 수

# %%
age_pi=pd.read_excel('./data/mismatch/울산동구 직종별 연령대별 피보험자 수.xlsx')

# %%
age_pi.head()
# Out:
#        마감년월       시군구      직종_중분류  연령_10세  피보험자수
# 0  2015년01월  울산광역시 중구  2005직종_관리직  20~29세     44
# 1       NaN       NaN         NaN  30~39세    363
# 2       NaN       NaN         NaN  40~49세    175
# 3       NaN       NaN         NaN  50~59세     80
# 4       NaN       NaN         NaN  60~69세     26

# %%
age_pi['마감년월'].fillna(method='ffill', inplace=True)
age_pi['시군구'].fillna(method='ffill', inplace=True)
age_pi['직종_중분류'].fillna(method='ffill', inplace=True)

age_pi.head()
# Out:
#        마감년월       시군구      직종_중분류  연령_10세  피보험자수
# 0  2015년01월  울산광역시 중구  2005직종_관리직  20~29세     44
# 1  2015년01월  울산광역시 중구  2005직종_관리직  30~39세    363
# 2  2015년01월  울산광역시 중구  2005직종_관리직  40~49세    175
# 3  2015년01월  울산광역시 중구  2005직종_관리직  50~59세     80
# 4  2015년01월  울산광역시 중구  2005직종_관리직  60~69세     26

# %%
split = age_pi.시군구.str.split()
split = split.apply(lambda x: pd.Series(x))
split.head()
# Out:
#        0   1
# 0  울산광역시  중구
# 1  울산광역시  중구
# 2  울산광역시  중구
# 3  울산광역시  중구
# 4  울산광역시  중구

# %%
tmp = pd.concat([age_pi, split], axis=1)

tmp.head()
# Out:
#        마감년월       시군구      직종_중분류  연령_10세  피보험자수      0   1
# 0  2015년01월  울산광역시 중구  2005직종_관리직  20~29세     44  울산광역시  중구
# 1  2015년01월  울산광역시 중구  2005직종_관리직  30~39세    363  울산광역시  중구
# 2  2015년01월  울산광역시 중구  2005직종_관리직  40~49세    175  울산광역시  중구
# 3  2015년01월  울산광역시 중구  2005직종_관리직  50~59세     80  울산광역시  중구
# 4  2015년01월  울산광역시 중구  2005직종_관리직  60~69세     26  울산광역시  중구

# %%
colnames = list(tmp.columns)
colnames[5:] = ['시도명','시군구명']
tmp.columns = colnames
tmp.head()
# Out:
#        마감년월       시군구      직종_중분류  연령_10세  피보험자수    시도명 시군구명
# 0  2015년01월  울산광역시 중구  2005직종_관리직  20~29세     44  울산광역시   중구
# 1  2015년01월  울산광역시 중구  2005직종_관리직  30~39세    363  울산광역시   중구
# 2  2015년01월  울산광역시 중구  2005직종_관리직  40~49세    175  울산광역시   중구
# 3  2015년01월  울산광역시 중구  2005직종_관리직  50~59세     80  울산광역시   중구
# 4  2015년01월  울산광역시 중구  2005직종_관리직  60~69세     26  울산광역시   중구

# %%
tmp.drop('시군구' , axis=1, inplace=True)

tmp.columns
# Out:
# Index(['마감년월', '직종_중분류', '연령_10세', '피보험자수', '시도명', '시군구명'], dtype='object')

# %%
age_pi = tmp[['마감년월', '시도명','시군구명','직종_중분류','연령_10세','피보험자수']]

age_pi.tail()
# Out:
#             마감년월    시도명 시군구명 직종_중분류  연령_10세  피보험자수
# 174045  2022년05월  울산광역시  울주군   분류불능  40~49세     14
# 174046  2022년05월  울산광역시  울주군   분류불능  50~59세     23
# 174047  2022년05월  울산광역시  울주군   분류불능  60~69세     19
# 174048  2022년05월  울산광역시  울주군   분류불능  70세 이상      1
# 174049  2022년05월  울산광역시  울주군   분류불능    분류불능      0

# %%
age_pi_donggu=age_pi[age_pi['시군구명']=="동구"]

# %%
age_pi_donggu.reset_index(drop=True, inplace=True)
age_pi_donggu.head()
# Out:
#        마감년월    시도명 시군구명      직종_중분류  연령_10세  피보험자수
# 0  2015년01월  울산광역시   동구  2005직종_관리직  20~29세     50
# 1  2015년01월  울산광역시   동구  2005직종_관리직  30~39세    194
# 2  2015년01월  울산광역시   동구  2005직종_관리직  40~49세     80
# 3  2015년01월  울산광역시   동구  2005직종_관리직  50~59세     64
# 4  2015년01월  울산광역시   동구  2005직종_관리직  60~69세     16

# %%
age_pi_donggu['직종_중분류'].unique()
# Out:
# array(['관리직', '경영,회계,사무관련직', '금융,보험관련직', '교육및자연과학 사회과학연구관련직',
#        '법률,경찰,소방교도 관련직', '보건,의료 관련직', '사회복지및 종교관련직', '문화,예술,디자인 방송관련직',
#        '운전및운송관련직', '구코드_고위임직원 및 관리자', '영업및판매관련직', '경비및청소관련직',
#        '미용,숙박,여행,오락,스포츠관련직', '음식서비스관련직', '건설 관련직', '기계관련직', '재료관련직',
#        '화학관련직', '섬유및의복관련직', '전기전자관련직', '구코드_전문가', '정보통신 관련직', '식품가공 관련직',
#        '환경,인쇄,목재,가구,공예및생산단순직', '농림어업 관련직', '구코드_기술공 및 준전문가', '구코드_사무직원',
#        '구코드_서비스근로자 및 상품화 시장판매근로자', '구코드_농업 및 어업 숙련근로자', '구코드_기능원 및 관련근로자',
#        '구코드_장치기계조작원 및 조립원', '구코드_단순노무직근로자', '구코드_분류불능', '분류불능',
#        '관리직(임원·부서장)', '경영·행정·사무직', '정보통신 연구개발직 및 공학기술직',
#        '건설·채굴 연구개발직 및 공학기술직', '제조 연구개발직 및 공학기술직', '교육직', '법률직',
#        '사회복지·종교직', '보건·의료직', '여행·숙박·오락 서비스직', '음식 서비스직', '경호·경비직',
#        '청소 및 기타 개인서비스직', '영업·판매직', '건설·채굴직', '기계 설치·정비·생산직',
#        '금속·재료 설치·정비·생산직(판금·단조·주조·용접·도장 등)', '전기·전자 설치·정비·생산직', '제조 단순직',
#        '예술·디자인·방송직', '스포츠·레크리에이션직', '미용·예식 서비스직', '돌봄 서비스직(간병·육아)',
# ...

# %%
for i in range(2005,2019):
    age_pi_donggu['직종_중분류']=age_pi_donggu['직종_중분류'].str.replace(str(i)+'직종_','')
# Out:
# C:\Users\jmjun\AppData\Local\Temp\ipykernel_10168\782298774.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   age_pi_donggu['직종_중분류']=age_pi_donggu['직종_중분류'].str.replace(str(i)+'직종_','')

# %%
age_pi_donggu[age_pi_donggu['직종_중분류']=='금속·재료 설치·정비·생산직(판금·단조·주조·용접·도장 등)']
# Out:
#            마감년월    시도명 시군구명                             직종_중분류  연령_10세  피보험자수
# 12633  2018년08월  울산광역시   동구  금속·재료 설치·정비·생산직(판금·단조·주조·용접·도장 등)  20~29세      8
# 12634  2018년08월  울산광역시   동구  금속·재료 설치·정비·생산직(판금·단조·주조·용접·도장 등)  30~39세      8
# 12635  2018년08월  울산광역시   동구  금속·재료 설치·정비·생산직(판금·단조·주조·용접·도장 등)  40~49세      9
# 12636  2018년08월  울산광역시   동구  금속·재료 설치·정비·생산직(판금·단조·주조·용접·도장 등)  50~59세      1
# 13019  2018년09월  울산광역시   동구  금속·재료 설치·정비·생산직(판금·단조·주조·용접·도장 등)  19세 이하      0
# 13020  2018년09월  울산광역시   동구  금속·재료 설치·정비·생산직(판금·단조·주조·용접·도장 등)  20~29세     20
# 13021  2018년09월  울산광역시   동구  금속·재료 설치·정비·생산직(판금·단조·주조·용접·도장 등)  30~39세     92
# 13022  2018년09월  울산광역시   동구  금속·재료 설치·정비·생산직(판금·단조·주조·용접·도장 등)  40~49세     90
# 13023  2018년09월  울산광역시   동구  금속·재료 설치·정비·생산직(판금·단조·주조·용접·도장 등)  50~59세     47
# 13024  2018년09월  울산광역시   동구  금속·재료 설치·정비·생산직(판금·단조·주조·용접·도장 등)  60~69세      7
# 13424  2018년10월  울산광역시   동구  금속·재료 설치·정비·생산직(판금·단조·주조·용접·도장 등)  20~29세     24
# ...

# %%
age_pi_donggu['직종_중분류']=age_pi_donggu['직종_중분류'].str.replace('재료관련직','금속·재료 설치·정비·생산직(판금·단조·주조·용접·도장 등)').str.replace('재료 관련직\(금속·유리·점토 및 시멘트\)','금속·재료 설치·정비·생산직(판금·단조·주조·용접·도장 등)')
# Out:
# C:\Users\jmjun\AppData\Local\Temp\ipykernel_10168\3769290209.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   age_pi_donggu['직종_중분류']=age_pi_donggu['직종_중분류'].str.replace('재료관련직','금속·재료 설치·정비·생산직(판금·단조·주조·용접·도장 등)').str.replace('재료 관련직\(금속·유리·점토 및 시멘트\)','금속·재료 설치·정비·생산직(판금·단조·주조·용접·도장 등)')
# C:\Users\jmjun\AppData\Local\Temp\ipykernel_10168\3769290209.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   age_pi_donggu['직종_중분류']=age_pi_donggu['직종_중분류'].str.replace('재료관련직','금속·재료 설치·정비·생산직(판금·단조·주조·용접·도장 등)').str.replace('재료 관련직\(금속·유리·점토 및 시멘트\)','금속·재료 설치·정비·생산직(판금·단조·주조·용접·도장 등)')

# %%
age_pi_donggu_gold=age_pi_donggu[age_pi_donggu['직종_중분류']=='금속·재료 설치·정비·생산직(판금·단조·주조·용접·도장 등)']

# %%
age_pi_donggu_gold.reset_index(drop=True, inplace=True)

# %%
age_pi_donggu_gold.head()
# Out:
#        마감년월    시도명 시군구명                             직종_중분류  연령_10세  피보험자수
# 0  2015년01월  울산광역시   동구  금속·재료 설치·정비·생산직(판금·단조·주조·용접·도장 등)  20~29세     52
# 1  2015년01월  울산광역시   동구  금속·재료 설치·정비·생산직(판금·단조·주조·용접·도장 등)  30~39세    311
# 2  2015년01월  울산광역시   동구  금속·재료 설치·정비·생산직(판금·단조·주조·용접·도장 등)  40~49세    441
# 3  2015년01월  울산광역시   동구  금속·재료 설치·정비·생산직(판금·단조·주조·용접·도장 등)  50~59세    369
# 4  2015년01월  울산광역시   동구  금속·재료 설치·정비·생산직(판금·단조·주조·용접·도장 등)  60~69세    103

# %%
age_pi_donggu_gold.to_csv('./data/mismatch/동구 직종 중분류_연령_피보험자수..csv',index=False)

# %% [markdown]
# ### 울산 동구 미스매치 여러 직종별

# %%
import pandas as pd
age_pi=pd.read_csv('./data/mismatch/원본/guin_donngu_중분류까지.csv',encoding='utf-8')

# %%
age_pi.head()
# Out:
#      STDR_YM    시도명 시군구명        직종_중분류                      고용형태  유효구인인원  \
# 0  2015년 01월  울산광역시   동구           관리직           기간의 정함이 없는 근로계약       5
# 1  2015년 01월  울산광역시   동구           관리직  기간의 정함이 없는 근로계약(시간(선택)제)       0
# 2  2015년 01월  울산광역시   동구           관리직           기간의 정함이 있는 근로계약       1
# 3  2015년 01월  울산광역시   동구           관리직                      관계없음       0
# 4  2015년 01월  울산광역시   동구  경영·회계·사무 관련직           기간의 정함이 없는 근로계약      26
#
#    유효구직자수
# 0      60
# 1       5
# 2       6
# 3      19
# 4     539

# %%
age_pi['직종_중분류']=age_pi['직종_중분류'].str.replace('재료 관련직\(금속·유리·점토 및 시멘트\)','금속·재료 설치·정비·생산직(판금·단조·주조·용접·도장 등)')
# Out:
# C:\Users\jmjun\AppData\Local\Temp\ipykernel_21048\4250416482.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   age_pi['직종_중분류']=age_pi['직종_중분류'].str.replace('재료 관련직\(금속·유리·점토 및 시멘트\)','금속·재료 설치·정비·생산직(판금·단조·주조·용접·도장 등)')

# %%
age_pi[age_pi['직종_중분류']=='금속·재료 설치·정비·생산직(판금·단조·주조·용접·도장 등)']
# Out:
#          STDR_YM    시도명 시군구명                             직종_중분류  \
# 71     2015년 01월  울산광역시   동구  금속·재료 설치·정비·생산직(판금·단조·주조·용접·도장 등)
# 72     2015년 01월  울산광역시   동구  금속·재료 설치·정비·생산직(판금·단조·주조·용접·도장 등)
# 73     2015년 01월  울산광역시   동구  금속·재료 설치·정비·생산직(판금·단조·주조·용접·도장 등)
# 74     2015년 01월  울산광역시   동구  금속·재료 설치·정비·생산직(판금·단조·주조·용접·도장 등)
# 75     2015년 01월  울산광역시   동구  금속·재료 설치·정비·생산직(판금·단조·주조·용접·도장 등)
# ...          ...    ...  ...                                ...
# 12050  2022년 05월  울산광역시   동구  금속·재료 설치·정비·생산직(판금·단조·주조·용접·도장 등)
# 12051  2022년 05월  울산광역시   동구  금속·재료 설치·정비·생산직(판금·단조·주조·용접·도장 등)
# 12052  2022년 05월  울산광역시   동구  금속·재료 설치·정비·생산직(판금·단조·주조·용접·도장 등)
# 12053  2022년 05월  울산광역시   동구  금속·재료 설치·정비·생산직(판금·단조·주조·용접·도장 등)
# 12054  2022년 05월  울산광역시   동구  금속·재료 설치·정비·생산직(판금·단조·주조·용접·도장 등)
#
#                            고용형태  유효구인인원  유효구직자수
# 71              기간의 정함이 없는 근로계약     427     201
# 72     기간의 정함이 없는 근로계약(시간(선택)제)       5       4
# 73              기간의 정함이 있는 근로계약      20      18
# ...

# %%
age_pi.to_csv('./data/mismatch/동구 여러 직종 고용형태 구인 구직.csv',index=False)

# %% [markdown]
# ### 울산 전체 피보험자수

# %%
one_data_dg=one_data[(one_data['CTPRVN_NM']=='울산광역시')]

one_data_dg.head()
# Out:
#      STDR_YM CTPRVN_NM SIGNGU_NM  LTRS_CO  중견기업수  중소기업수  TOT_ENTRPRS_CO  \
# 150  2015-11     울산광역시        남구       20     32   4326            1820
# 151  2015-11     울산광역시        동구        4      3    665             365
# 152  2015-11     울산광역시        북구        0     11   1447             833
# 153  2015-11     울산광역시       울주군       16     33   3812            2107
# 154  2015-11     울산광역시        중구        2      1   1383             528
#
#      EMPLY_CO  ECNY_CO  RETIRE_CO        지급액  수출건수     수출금액  수입건수     수입금액  \
# 150     31265     1180       1091  196456480  7844  1228839  6210   269156
# 151     25323     1932       1788   76422400  2534  3515864  5486   324452
# 152     21298      753        718   73744620  3848  1518623  3564   104433
# 153     39087     1485       1479   95273110  4353  1107229  4797  1554565
# 154     16833      265        322  122712790   146     3342  2461   135347
#
#         무역수지  피보험자수  취득자수  상실자수  수급자격신청자수  수급자격인정자수  실업급여지급자수  실업급여지급건수  \
# ...

# %%
pd.set_option('display.max_columns', None)

pd.set_option('display.max_rows', None)

import os
import os.path

pd.set_option('display.max_columns', None)

pd.set_option('display.max_rows', None)

from matplotlib import font_manager, rc

font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

# %%
# %matplotlib inline

columns=one_data_dg.columns

columns
# Out:
# Index(['STDR_YM', 'CTPRVN_NM', 'SIGNGU_NM', 'LTRS_CO', '중견기업수', '중소기업수',
#        'TOT_ENTRPRS_CO', 'EMPLY_CO', 'ECNY_CO', 'RETIRE_CO', '지급액', '수출건수',
#        '수출금액', '수입건수', '수입금액', '무역수지', '피보험자수', '취득자수', '상실자수', '수급자격신청자수',
#        '수급자격인정자수', '실업급여지급자수', '실업급여지급건수', '실업급여지급액', '신규성립사업장수', '소멸사업장수',
#        'elec_use'],
#       dtype='object')

# %%
one_data_dg=one_data[(one_data['CTPRVN_NM']=='울산광역시')][['STDR_YM', 'CTPRVN_NM', 'SIGNGU_NM','피보험자수']]

# %%
one_data_dg.reset_index(drop=True)
# Out:
#      STDR_YM CTPRVN_NM SIGNGU_NM  피보험자수
# 0    2015-11     울산광역시        남구  84211
# 1    2015-11     울산광역시        동구  73139
# 2    2015-11     울산광역시        북구  70788
# 3    2015-11     울산광역시       울주군  67471
# 4    2015-11     울산광역시        중구  30110
# 5    2015-12     울산광역시        남구  83447
# 6    2015-12     울산광역시        동구  73083
# 7    2015-12     울산광역시        북구  70546
# 8    2015-12     울산광역시       울주군  67166
# 9    2015-12     울산광역시        중구  28733
# 10   2016-01     울산광역시        남구  81269
# 11   2016-01     울산광역시        동구  72282
# 12   2016-01     울산광역시        북구  70009
# 13   2016-01     울산광역시       울주군  67199
# 14   2016-01     울산광역시        중구  28169
# 15   2016-02     울산광역시        남구  82123
# 16   2016-02     울산광역시        동구  71768
# 17   2016-02     울산광역시        북구  70446
# 18   2016-02     울산광역시       울주군  67053
# 19   2016-02     울산광역시        중구  28295
# 20   2016-03     울산광역시        남구  83136
# 21   2016-03     울산광역시        동구  71073
# ...

# %%
one_data_dg.to_csv('./data/울산 전체 피보험자수.csv',index=False)

# %%
for i in one_data_dg.columns:
    y1=one_data_dg[str(i)]
    x=one_data_dg['STDR_YM']
    fig,ax1 = plt.subplots(figsize=(20,10))
    ax=ax1.plot(x, y1, color = '#c02ad1', alpha = 0.5,label=i,linestyle='solid', linewidth=3)
    plt.legend(loc='upper left')
    plt.xlabel("시간")
    plt.ylabel("Data")
    plt.xticks(rotation=45) 
    plt.grid(False)
    plt.tight_layout()        
    plt.savefig('./미스매치 결과/'+str(i)+'.png',facecolor='#eeeeee',edgecolor='black',format='png', dpi=100,box_inches='tight',pad_inches=4)

### 유효구인 구직(정규직 비정규직)

goyongtype.시군구

goyongtype['STDR_YM'].fillna(method='ffill', inplace=True)
goyongtype['시군구'].fillna(method='ffill', inplace=True)

goyongtype.head()

split = goyongtype.시군구.str.split()
split = split.apply(lambda x: pd.Series(x))
split

tmp = pd.concat([goyongtype, split], axis=1)

tmp

colnames = list(tmp.columns)
colnames[5:] = ['시도명','시군구명']
tmp.columns = colnames
tmp

tmp.drop('시군구' , axis=1, inplace=True)

tmp.columns

goyongtype_final = tmp[['STDR_YM', '시도명','시군구명','고용형태','유효구인인원','유효구직자수']]

goyongtype_final

goyongtype_final.columns = ['STDR_YM','CTPRVN_NM','SIGNGU_NM','고용형태','유효구인인원','유효구직자수']

goyongtype_final

goyongtype_final_dongu=goyongtype_final[goyongtype_final['SIGNGU_NM']=='동구']

goyongtype_final_dongu.reset_index(drop=True)

goyongtype_final_dongu.to_csv('./data/mismatch/goyongtype_final_dongu.csv',index=False)
